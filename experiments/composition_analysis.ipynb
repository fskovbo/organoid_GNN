# %% [markdown]
# # Composition analysis
#
# Given the organoid graphs, curvature predictions can depends on multiple sources of information. A useful decomposition is:
#
# \begin{equation}
# \mathbb{E}[\kappa_i \mid \text{data}] \approx
# \underbrace{f_{\text{structure}}}_{\text{packing / positional context}}
# +
# \underbrace{f_{\text{center marker}}}_{\text{cell identity}}
# +
# \underbrace{f_{\text{neighborhood markers}}}_{\text{local composition}}
# +
# \epsilon.
# \end{equation}
#
# Similarly, predictive uncertainty may depend on:
#
# \begin{equation}
# \mathrm{Var}(\kappa_i \mid \text{data}) \approx
# g_{\text{composition ambiguity}} +
# g_{\text{structural heterogeneity}}.
# \end{equation}
#
#
# These experiments probe which parts of the local tissue context drive curvature prediction.
#
# We compare three model families:
# - **GIN**: a message-passing GNN that can, in principle, exploit fine neighborhood arrangement.
# - **Ring-fraction MLP**: uses marker fractions in exact hop rings and therefore retains coarse radial composition.
# - **Ring-size MLP**: uses only ring sizes (local graph structure / packing) together with the center-cell identity.
#
# The overall goal is to separate the roles of:
# 1. **center-cell identity**,
# 2. **neighborhood marker composition**, and
# 3. **coarse local structure / packing**.
#
# Excellent idea 👍 — having a **single experimental overview block** will make the notebook (and later a paper / talk) much easier to follow.
#
# Here is a clean, compact version you can paste near the top.
#
# ---
#
# ## Experimental overview: probing the role of neighborhood composition
#
# We study how much information about local membrane curvature is carried by **cell fate markers and their spatial organization** in intestinal organoid graphs.
#
# Models are always **trained on the original organoid graphs**.
# Differences between experiments arise only from how neighborhood marker structure is perturbed during **evaluation**.
#
# We compare three evaluation conditions:
#
# ### Experiment 1 — Original neighborhood structure
#
# Models are evaluated on ego-subgraphs built from the unmodified validation organoids.
#
# This represents the full biological signal:
#
# * center marker identity,
# * neighborhood marker composition,
# * fine spatial organization of cells.
#
# Performance here defines the **reference level** for all comparisons.
#
# ---
#
# ### Experiment 2 — Center-preserving neighborhood permutation
#
# Marker features are randomly permuted within each organoid, destroying spatial correlations between neighboring cell types.
# Ego-subgraphs are then rebuilt around sampled centers, with the **center marker restored to its original value**.
#
# This removes information about **which markers surround a cell**, while keeping:
#
# * center marker identity,
# * curvature targets,
# * global marker frequencies.
#
# Performance degradation relative to Experiment 1 quantifies the contribution of **informative neighborhood composition**.
#
# ---
#
# ### Experiment 3 — Ring-preserving permutation
#
# Marker features are permuted **only within each k-hop ring**, preserving how many cells of each type occur at each distance scale but destroying finer spatial ordering.
#
# This keeps **coarse multi-scale composition** intact while removing **fine spatial structure** such as clustering or directional organization.
#
# Comparing performance across Experiments 1–3 allows us to disentangle the roles of:
#
# * center marker identity
# * coarse neighborhood composition
# * fine spatial arrangement and topology
#
# in predicting local curvature.
#
# ---
#
# ### Model comparison
#
# We evaluate multiple model families with different spatial expressivity:
#
# * Graph neural networks (message passing with topology awareness)
# * Ring-based MLP models (composition-only representations)
# * Pooled variants capturing cumulative multi-hop statistics
#
# Performance trends across depth and perturbation conditions help determine **which spatial scales and representations carry predictive biological signal**.

# %% [markdown]
# ## Setup and training

# %% [markdown]
# ### Specify model and training parameters

# %%
import numpy as np
import matplotlib.pyplot as plt

K_MAX = 9

base_hidden_dim = 4*64
base_dropout = 0.1
base_norm = "batch"

lr = 1e-3
batch_size = 128
max_epochs = 2000
patience = 100

trained_model_families = {
    "GIN": [],
    "ring-fraction": [],
    "ring-size": [],
}

depths = np.arange(0, K_MAX)

# %% [markdown]
# ### Load and process data

# %%
import torch

import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
DATA_ROOT = PROJECT_ROOT / "training_data"

sys.path.append(str(PROJECT_ROOT))

print("PROJECT_ROOT =", PROJECT_ROOT)
print("DATA_ROOT    =", DATA_ROOT)
# Out:
# PROJECT_ROOT = /home/fmoller/Projects/LearningOrganoids/GraphNN
# DATA_ROOT    = /home/fmoller/Projects/LearningOrganoids/GraphNN/training_data

# %%
from src.data.io import load_graph_dataset_from_dir
from src.data.metadata import load_aux_metadata_for_dir, attach_metadata_to_graphs, load_marker_names_from_dir

# Load all organoids
data_dir = PROJECT_ROOT / "training_data" / "full_set"
graphs = load_graph_dataset_from_dir(str(data_dir))
print(f"Loaded {len(graphs)} organoids.")

meta = load_aux_metadata_for_dir(str(data_dir))
attached = attach_metadata_to_graphs(
    graphs,
    meta,
    exclude_keys=["graph_path", "seg_path"],
)
print(f"Attached metadata to {attached}/{len(graphs)} graphs.")

marker_names = load_marker_names_from_dir(str(data_dir))
# Out:
# Loaded 1224 graphs; skipped 0.
# Loaded 1224 organoids.
# Attached metadata to 1224/1224 graphs.

# %%
from src.data.metadata import ensure_metadata_keys

graphs = ensure_metadata_keys(
    graphs,
    required_keys=["complexity", "dataset", "timepoint", "num_nodes"],
    defaults={
        "complexity": np.nan,
        "dataset": None,
        "timepoint": None,
        "num_nodes": np.nan,
    },
    inplace=False,
)


complexities = np.array([
    np.nan if getattr(g, "meta", {}).get("complexity", None) is None
    else float(getattr(g, "meta", {}).get("complexity"))
    for g in graphs
], dtype=float)

mask_keep = (~np.isfinite(complexities)) | (complexities >= 1.0)

graphs = [g for g, keep in zip(graphs, mask_keep) if keep]

print(f"After complexity filter: {len(graphs)} organoids.")
# Out:
# After complexity filter: 881 organoids.

# %%
from src.data.preprocessing import subtract_organoid_mean_curvature

graphs = subtract_organoid_mean_curvature(graphs, inplace=False)

# %%
from src.data.metadata import strip_graph_metadata
from src.data.splits import standardize_graph_targets, train_val_split_graphs

graphs = strip_graph_metadata(graphs, inplace=False)


# Split dataset by organoid
g_train, g_val = train_val_split_graphs(graphs, val_frac=0.2, seed=None)
print(f"Split -> train: {len(g_train)} | val: {len(g_val)}")

center, scale = standardize_graph_targets(g_train, g_val, robust=True)
# Out:
# Split -> train: 705 | val: 176

# %%
from src.data.ring_features import attach_precomputed_ring_features

g_train = attach_precomputed_ring_features(
    g_train,
    k_hops=K_MAX,
    inplace=False,
)

g_val = attach_precomputed_ring_features(
    g_val,
    k_hops=K_MAX,
    inplace=False,
)

# %% [markdown]
# ### Train models on organoid graphs

# %%
from src.training.loop import TrainConfig, train

cfg = TrainConfig(
    loss_name="gaussian",
    lr=lr,
    batch_size=batch_size,
    max_epochs=max_epochs,
    patience=patience,
    num_workers=4,
)

device = cfg.device if "cfg" in globals() else ("cuda" if torch.cuda.is_available() else "cpu")

# %%
from src.models.gnn import GINCurvature
from src.models.ring_mlp import RingFractionMLP, RingSizeMLP

for family in trained_model_families.keys():

    for k in depths:
        print(f"\n=== Training {family} model with depth={k} ===")

        n_markers = int(g_train[0].x.size(1))

        if family == "GIN":
            model_kwargs = {
                "n_markers": n_markers,
                "hidden_dim": base_hidden_dim,
                "num_layers": int(k),
                "dropout": base_dropout,
                "residual": True,
                "norm": base_norm,
                "train_eps": True,
            }
            model = GINCurvature(**model_kwargs)

        elif family == "ring-fraction":
            model_kwargs = {
                "n_markers": n_markers,
                "k_hops": int(k),
                "hidden_dim": base_hidden_dim,
                "dropout": base_dropout,
                "norm": base_norm,
            }
            model = RingFractionMLP(**model_kwargs)

        elif family == "ring-size":
            model_kwargs = {
                "n_markers": n_markers,
                "k_hops": int(k),
                "hidden_dim": base_hidden_dim,
                "dropout": base_dropout,
                "norm": base_norm,
            }
            model = RingSizeMLP(**model_kwargs)

        else:
            raise ValueError(f"Unknown family: {family}")


        model, metrics, history = train(model, g_train, g_val, cfg)
        trained_model_families[family].append(model)
# Out:
# === Training GIN model with depth=0 ===
# epoch 001 | train loss 1.3466 mae 1.0082 | val loss 1.2193 mae 1.0322
# epoch 002 | train loss 1.1175 mae 0.9937 | val loss 1.0657 mae 1.0323
# epoch 003 | train loss 0.9946 mae 0.9942 | val loss 0.9887 mae 1.0326
# epoch 004 | train loss 0.9411 mae 0.9946 | val loss 0.9515 mae 1.0276
# epoch 005 | train loss 0.9143 mae 0.9911 | val loss 0.9328 mae 1.0201
# epoch 006 | train loss 0.8996 mae 0.9866 | val loss 0.9214 mae 1.0138
# epoch 007 | train loss 0.8895 mae 0.9835 | val loss 0.9131 mae 1.0108
# epoch 008 | train loss 0.8804 mae 0.9825 | val loss 0.9069 mae 1.0103
# epoch 009 | train loss 0.8738 mae 0.9837 | val loss 0.9029 mae 1.0111
# epoch 010 | train loss 0.8683 mae 0.9844 | val loss 0.9012 mae 1.0114
# epoch 011 | train loss 0.8658 mae 0.9849 | val loss 0.9003 mae 1.0110
# epoch 012 | train loss 0.8637 mae 0.9839 | val loss 0.8989 mae 1.0089
# epoch 013 | train loss 0.8608 mae 0.9823 | val loss 0.8978 mae 1.0074
# epoch 014 | train loss 0.8600 mae 0.9816 | val loss 0.8962 mae 1.0060
# epoch 015 | train loss 0.8586 mae 0.9799 | val loss 0.8952 mae 1.0045
# epoch 016 | train loss 0.8584 mae 0.9788 | val loss 0.8942 mae 1.0031
# epoch 017 | train loss 0.8564 mae 0.9784 | val loss 0.8938 mae 1.0034
# epoch 018 | train loss 0.8565 mae 0.9785 | val loss 0.8935 mae 1.0030
# epoch 019 | train loss 0.8563 mae 0.9781 | val loss 0.8931 mae 1.0025
# epoch 020 | train loss 0.8557 mae 0.9780 | val loss 0.8927 mae 1.0024
# epoch 021 | train loss 0.8564 mae 0.9778 | val loss 0.8923 mae 1.0021
# epoch 022 | train loss 0.8560 mae 0.9784 | val loss 0.8922 mae 1.0020
# epoch 023 | train loss 0.8557 mae 0.9774 | val loss 0.8917 mae 1.0007
# epoch 024 | train loss 0.8543 mae 0.9767 | val loss 0.8913 mae 1.0008
# epoch 025 | train loss 0.8548 mae 0.9780 | val loss 0.8905 mae 1.0020
# epoch 026 | train loss 0.8548 mae 0.9794 | val loss 0.8901 mae 1.0030
# epoch 027 | train loss 0.8543 mae 0.9794 | val loss 0.8896 mae 1.0017
# epoch 028 | train loss 0.8534 mae 0.9786 | val loss 0.8901 mae 1.0015
# epoch 029 | train loss 0.8538 mae 0.9777 | val loss 0.8899 mae 1.0004
# epoch 030 | train loss 0.8530 mae 0.9776 | val loss 0.8899 mae 1.0012
# epoch 031 | train loss 0.8537 mae 0.9772 | val loss 0.8886 mae 0.9998
# epoch 032 | train loss 0.8539 mae 0.9761 | val loss 0.8887 mae 0.9997
# epoch 033 | train loss 0.8532 mae 0.9780 | val loss 0.8890 mae 1.0022
# epoch 034 | train loss 0.8534 mae 0.9791 | val loss 0.8884 mae 1.0020
# epoch 035 | train loss 0.8526 mae 0.9787 | val loss 0.8881 mae 1.0009
# epoch 036 | train loss 0.8529 mae 0.9780 | val loss 0.8884 mae 1.0011
# epoch 037 | train loss 0.8524 mae 0.9779 | val loss 0.8890 mae 1.0005
# epoch 038 | train loss 0.8517 mae 0.9772 | val loss 0.8885 mae 1.0004
# epoch 039 | train loss 0.8517 mae 0.9778 | val loss 0.8889 mae 1.0013
# epoch 040 | train loss 0.8529 mae 0.9779 | val loss 0.8883 mae 1.0006
# epoch 041 | train loss 0.8523 mae 0.9775 | val loss 0.8887 mae 1.0006
# epoch 042 | train loss 0.8513 mae 0.9764 | val loss 0.8888 mae 0.9994
# epoch 043 | train loss 0.8519 mae 0.9757 | val loss 0.8883 mae 0.9996
# epoch 044 | train loss 0.8521 mae 0.9761 | val loss 0.8887 mae 1.0000
# epoch 045 | train loss 0.8518 mae 0.9762 | val loss 0.8888 mae 1.0004
# epoch 046 | train loss 0.8524 mae 0.9769 | val loss 0.8889 mae 1.0008
# epoch 047 | train loss 0.8505 mae 0.9768 | val loss 0.8881 mae 1.0000
# epoch 048 | train loss 0.8514 mae 0.9764 | val loss 0.8880 mae 1.0001
# epoch 049 | train loss 0.8529 mae 0.9768 | val loss 0.8876 mae 1.0008
# epoch 050 | train loss 0.8503 mae 0.9773 | val loss 0.8881 mae 1.0013
# epoch 051 | train loss 0.8513 mae 0.9777 | val loss 0.8880 mae 1.0008
# epoch 052 | train loss 0.8520 mae 0.9768 | val loss 0.8878 mae 0.9998
# epoch 053 | train loss 0.8522 mae 0.9761 | val loss 0.8873 mae 1.0002
# epoch 054 | train loss 0.8507 mae 0.9783 | val loss 0.8872 mae 1.0025
# epoch 055 | train loss 0.8510 mae 0.9788 | val loss 0.8875 mae 1.0015
# epoch 056 | train loss 0.8510 mae 0.9772 | val loss 0.8883 mae 0.9994
# epoch 057 | train loss 0.8512 mae 0.9760 | val loss 0.8885 mae 0.9998
# epoch 058 | train loss 0.8514 mae 0.9757 | val loss 0.8887 mae 0.9997
# epoch 059 | train loss 0.8531 mae 0.9762 | val loss 0.8876 mae 1.0006
# epoch 060 | train loss 0.8505 mae 0.9775 | val loss 0.8879 mae 1.0016
# epoch 061 | train loss 0.8516 mae 0.9778 | val loss 0.8882 mae 1.0007
# epoch 062 | train loss 0.8507 mae 0.9765 | val loss 0.8889 mae 0.9995
# epoch 063 | train loss 0.8511 mae 0.9752 | val loss 0.8905 mae 0.9991
# epoch 064 | train loss 0.8503 mae 0.9744 | val loss 0.8895 mae 0.9989
# epoch 065 | train loss 0.8503 mae 0.9751 | val loss 0.8889 mae 1.0001
# epoch 066 | train loss 0.8496 mae 0.9761 | val loss 0.8889 mae 1.0002
# epoch 067 | train loss 0.8500 mae 0.9751 | val loss 0.8883 mae 0.9991
# epoch 068 | train loss 0.8495 mae 0.9765 | val loss 0.8882 mae 1.0017
# epoch 069 | train loss 0.8502 mae 0.9780 | val loss 0.8873 mae 1.0013
# epoch 070 | train loss 0.8492 mae 0.9783 | val loss 0.8876 mae 1.0021
# epoch 071 | train loss 0.8495 mae 0.9777 | val loss 0.8879 mae 1.0003
# epoch 072 | train loss 0.8490 mae 0.9763 | val loss 0.8877 mae 1.0003
# epoch 073 | train loss 0.8496 mae 0.9764 | val loss 0.8874 mae 1.0003
# epoch 074 | train loss 0.8497 mae 0.9758 | val loss 0.8873 mae 0.9998
# epoch 075 | train loss 0.8494 mae 0.9764 | val loss 0.8876 mae 1.0013
# epoch 076 | train loss 0.8492 mae 0.9772 | val loss 0.8882 mae 1.0011
# epoch 077 | train loss 0.8507 mae 0.9759 | val loss 0.8877 mae 0.9993
# epoch 078 | train loss 0.8490 mae 0.9760 | val loss 0.8885 mae 1.0013
# epoch 079 | train loss 0.8505 mae 0.9773 | val loss 0.8883 mae 1.0008
# epoch 080 | train loss 0.8496 mae 0.9758 | val loss 0.8877 mae 0.9996
# epoch 081 | train loss 0.8497 mae 0.9752 | val loss 0.8883 mae 1.0002
# epoch 082 | train loss 0.8497 mae 0.9763 | val loss 0.8873 mae 1.0012
# epoch 083 | train loss 0.8500 mae 0.9773 | val loss 0.8875 mae 1.0016
# epoch 084 | train loss 0.8501 mae 0.9775 | val loss 0.8889 mae 1.0008
# epoch 085 | train loss 0.8486 mae 0.9757 | val loss 0.8882 mae 0.9990
# epoch 086 | train loss 0.8503 mae 0.9741 | val loss 0.8876 mae 0.9988
# epoch 087 | train loss 0.8497 mae 0.9756 | val loss 0.8872 mae 1.0009
# epoch 088 | train loss 0.8502 mae 0.9770 | val loss 0.8872 mae 1.0010
# epoch 089 | train loss 0.8497 mae 0.9763 | val loss 0.8876 mae 0.9997
# epoch 090 | train loss 0.8498 mae 0.9763 | val loss 0.8875 mae 1.0019
# epoch 091 | train loss 0.8503 mae 0.9778 | val loss 0.8873 mae 1.0019
# epoch 092 | train loss 0.8490 mae 0.9767 | val loss 0.8874 mae 0.9998
# epoch 093 | train loss 0.8496 mae 0.9763 | val loss 0.8878 mae 1.0009
# epoch 094 | train loss 0.8495 mae 0.9770 | val loss 0.8878 mae 1.0012
# epoch 095 | train loss 0.8494 mae 0.9760 | val loss 0.8880 mae 0.9994
# epoch 096 | train loss 0.8497 mae 0.9750 | val loss 0.8888 mae 0.9994
# epoch 097 | train loss 0.8487 mae 0.9753 | val loss 0.8868 mae 0.9999
# epoch 098 | train loss 0.8503 mae 0.9765 | val loss 0.8869 mae 1.0016
# epoch 099 | train loss 0.8491 mae 0.9777 | val loss 0.8876 mae 1.0016
# epoch 100 | train loss 0.8490 mae 0.9776 | val loss 0.8878 mae 1.0009
# epoch 101 | train loss 0.8501 mae 0.9775 | val loss 0.8877 mae 1.0016
# epoch 102 | train loss 0.8490 mae 0.9777 | val loss 0.8877 mae 1.0012
# epoch 103 | train loss 0.8498 mae 0.9763 | val loss 0.8876 mae 1.0001
# epoch 104 | train loss 0.8501 mae 0.9771 | val loss 0.8874 mae 1.0023
# epoch 105 | train loss 0.8497 mae 0.9783 | val loss 0.8876 mae 1.0017
# epoch 106 | train loss 0.8506 mae 0.9775 | val loss 0.8879 mae 1.0015
# epoch 107 | train loss 0.8488 mae 0.9762 | val loss 0.8890 mae 0.9997
# epoch 108 | train loss 0.8487 mae 0.9748 | val loss 0.8888 mae 0.9991
# epoch 109 | train loss 0.8490 mae 0.9744 | val loss 0.8889 mae 0.9995
# epoch 110 | train loss 0.8494 mae 0.9754 | val loss 0.8876 mae 1.0005
# epoch 111 | train loss 0.8491 mae 0.9766 | val loss 0.8876 mae 1.0015
# epoch 112 | train loss 0.8497 mae 0.9777 | val loss 0.8877 mae 1.0022
# epoch 113 | train loss 0.8493 mae 0.9776 | val loss 0.8880 mae 1.0017
# epoch 114 | train loss 0.8496 mae 0.9782 | val loss 0.8885 mae 1.0023
# epoch 115 | train loss 0.8491 mae 0.9773 | val loss 0.8888 mae 1.0003
# epoch 116 | train loss 0.8486 mae 0.9753 | val loss 0.8885 mae 0.9999
# epoch 117 | train loss 0.8493 mae 0.9761 | val loss 0.8891 mae 1.0017
# epoch 118 | train loss 0.8487 mae 0.9766 | val loss 0.8886 mae 1.0000
# epoch 119 | train loss 0.8485 mae 0.9746 | val loss 0.8884 mae 0.9986
# epoch 120 | train loss 0.8488 mae 0.9744 | val loss 0.8877 mae 0.9997
# epoch 121 | train loss 0.8489 mae 0.9770 | val loss 0.8875 mae 1.0026
# epoch 122 | train loss 0.8503 mae 0.9799 | val loss 0.8875 mae 1.0040
# epoch 123 | train loss 0.8500 mae 0.9779 | val loss 0.8877 mae 0.9994
# epoch 124 | train loss 0.8497 mae 0.9748 | val loss 0.8879 mae 0.9996
# epoch 125 | train loss 0.8506 mae 0.9770 | val loss 0.8898 mae 1.0027
# epoch 126 | train loss 0.8493 mae 0.9766 | val loss 0.8885 mae 0.9990
# epoch 127 | train loss 0.8485 mae 0.9738 | val loss 0.8877 mae 0.9987
# epoch 128 | train loss 0.8487 mae 0.9752 | val loss 0.8880 mae 1.0017
# epoch 129 | train loss 0.8504 mae 0.9780 | val loss 0.8881 mae 1.0026
# epoch 130 | train loss 0.8485 mae 0.9769 | val loss 0.8881 mae 0.9998
# epoch 131 | train loss 0.8494 mae 0.9756 | val loss 0.8884 mae 1.0002
# epoch 132 | train loss 0.8495 mae 0.9760 | val loss 0.8890 mae 1.0008
# epoch 133 | train loss 0.8486 mae 0.9772 | val loss 0.8891 mae 1.0025
# epoch 134 | train loss 0.8491 mae 0.9775 | val loss 0.8887 mae 1.0009
# epoch 135 | train loss 0.8490 mae 0.9766 | val loss 0.8884 mae 1.0003
# epoch 136 | train loss 0.8495 mae 0.9751 | val loss 0.8886 mae 0.9998
# epoch 137 | train loss 0.8494 mae 0.9765 | val loss 0.8882 mae 1.0019
# epoch 138 | train loss 0.8483 mae 0.9765 | val loss 0.8870 mae 1.0004
# epoch 139 | train loss 0.8501 mae 0.9767 | val loss 0.8875 mae 1.0016
# epoch 140 | train loss 0.8496 mae 0.9782 | val loss 0.8889 mae 1.0024
# epoch 141 | train loss 0.8494 mae 0.9760 | val loss 0.8893 mae 0.9984
# epoch 142 | train loss 0.8489 mae 0.9735 | val loss 0.8892 mae 0.9990
# epoch 143 | train loss 0.8493 mae 0.9757 | val loss 0.8880 mae 1.0016
# epoch 144 | train loss 0.8489 mae 0.9765 | val loss 0.8875 mae 1.0008
# epoch 145 | train loss 0.8493 mae 0.9771 | val loss 0.8879 mae 1.0022
# epoch 146 | train loss 0.8484 mae 0.9781 | val loss 0.8890 mae 1.0019
# epoch 147 | train loss 0.8486 mae 0.9758 | val loss 0.8881 mae 0.9988
# epoch 148 | train loss 0.8488 mae 0.9730 | val loss 0.8881 mae 0.9981
# epoch 149 | train loss 0.8491 mae 0.9746 | val loss 0.8881 mae 1.0012
# epoch 150 | train loss 0.8484 mae 0.9779 | val loss 0.8886 mae 1.0031
# epoch 151 | train loss 0.8493 mae 0.9769 | val loss 0.8880 mae 0.9995
# epoch 152 | train loss 0.8478 mae 0.9752 | val loss 0.8884 mae 1.0008
# epoch 153 | train loss 0.8494 mae 0.9786 | val loss 0.8897 mae 1.0040
# epoch 154 | train loss 0.8491 mae 0.9778 | val loss 0.8888 mae 0.9995
# epoch 155 | train loss 0.8491 mae 0.9741 | val loss 0.8880 mae 0.9985
# epoch 156 | train loss 0.8500 mae 0.9748 | val loss 0.8877 mae 1.0006
# epoch 157 | train loss 0.8507 mae 0.9780 | val loss 0.8881 mae 1.0035
# epoch 158 | train loss 0.8495 mae 0.9792 | val loss 0.8891 mae 1.0025
# epoch 159 | train loss 0.8484 mae 0.9779 | val loss 0.8890 mae 1.0005
# epoch 160 | train loss 0.8485 mae 0.9759 | val loss 0.8891 mae 1.0006
# epoch 161 | train loss 0.8489 mae 0.9768 | val loss 0.8894 mae 1.0020
# epoch 162 | train loss 0.8488 mae 0.9772 | val loss 0.8892 mae 1.0011
# epoch 163 | train loss 0.8491 mae 0.9756 | val loss 0.8880 mae 0.9997
# epoch 164 | train loss 0.8488 mae 0.9755 | val loss 0.8878 mae 1.0004
# epoch 165 | train loss 0.8491 mae 0.9765 | val loss 0.8877 mae 1.0011
# epoch 166 | train loss 0.8485 mae 0.9770 | val loss 0.8884 mae 1.0009
# epoch 167 | train loss 0.8482 mae 0.9749 | val loss 0.8891 mae 0.9988
# epoch 168 | train loss 0.8488 mae 0.9744 | val loss 0.8894 mae 1.0006
# epoch 169 | train loss 0.8491 mae 0.9757 | val loss 0.8892 mae 1.0012
# epoch 170 | train loss 0.8484 mae 0.9766 | val loss 0.8886 mae 1.0015
# epoch 171 | train loss 0.8487 mae 0.9770 | val loss 0.8882 mae 1.0017
# epoch 172 | train loss 0.8487 mae 0.9777 | val loss 0.8886 mae 1.0022
# epoch 173 | train loss 0.8493 mae 0.9774 | val loss 0.8885 mae 1.0010
# epoch 174 | train loss 0.8495 mae 0.9775 | val loss 0.8896 mae 1.0017
# epoch 175 | train loss 0.8490 mae 0.9765 | val loss 0.8892 mae 1.0001
# epoch 176 | train loss 0.8492 mae 0.9748 | val loss 0.8895 mae 0.9990
# epoch 177 | train loss 0.8488 mae 0.9747 | val loss 0.8889 mae 1.0007
# epoch 178 | train loss 0.8489 mae 0.9761 | val loss 0.8888 mae 1.0009
# epoch 179 | train loss 0.8491 mae 0.9774 | val loss 0.8894 mae 1.0017
# epoch 180 | train loss 0.8491 mae 0.9760 | val loss 0.8893 mae 0.9999
# epoch 181 | train loss 0.8484 mae 0.9755 | val loss 0.8885 mae 1.0012
# epoch 182 | train loss 0.8495 mae 0.9781 | val loss 0.8880 mae 1.0035
# epoch 183 | train loss 0.8479 mae 0.9776 | val loss 0.8877 mae 1.0006
# epoch 184 | train loss 0.8486 mae 0.9756 | val loss 0.8879 mae 0.9998
# epoch 185 | train loss 0.8488 mae 0.9759 | val loss 0.8887 mae 1.0013
# epoch 186 | train loss 0.8487 mae 0.9766 | val loss 0.8883 mae 1.0004
# epoch 187 | train loss 0.8485 mae 0.9759 | val loss 0.8881 mae 1.0005
# epoch 188 | train loss 0.8490 mae 0.9772 | val loss 0.8883 mae 1.0024
# epoch 189 | train loss 0.8489 mae 0.9778 | val loss 0.8871 mae 1.0017
# epoch 190 | train loss 0.8492 mae 0.9787 | val loss 0.8880 mae 1.0027
# epoch 191 | train loss 0.8476 mae 0.9774 | val loss 0.8885 mae 1.0009
# epoch 192 | train loss 0.8501 mae 0.9766 | val loss 0.8898 mae 1.0011
# epoch 193 | train loss 0.8490 mae 0.9756 | val loss 0.8877 mae 0.9997
# epoch 194 | train loss 0.8482 mae 0.9753 | val loss 0.8881 mae 1.0004
# epoch 195 | train loss 0.8487 mae 0.9757 | val loss 0.8878 mae 1.0000
# epoch 196 | train loss 0.8494 mae 0.9749 | val loss 0.8880 mae 1.0002
# epoch 197 | train loss 0.8482 mae 0.9776 | val loss 0.8885 mae 1.0033
# epoch 198 | train loss 0.8484 mae 0.9776 | val loss 0.8883 mae 1.0005
# epoch 199 | train loss 0.8492 mae 0.9746 | val loss 0.8882 mae 0.9991
# epoch 200 | train loss 0.8488 mae 0.9753 | val loss 0.8881 mae 1.0013
# epoch 201 | train loss 0.8482 mae 0.9759 | val loss 0.8878 mae 1.0002
# epoch 202 | train loss 0.8484 mae 0.9758 | val loss 0.8879 mae 1.0010
# epoch 203 | train loss 0.8494 mae 0.9770 | val loss 0.8884 mae 1.0020
# epoch 204 | train loss 0.8489 mae 0.9773 | val loss 0.8887 mae 1.0009
# epoch 205 | train loss 0.8489 mae 0.9763 | val loss 0.8881 mae 1.0007
# epoch 206 | train loss 0.8489 mae 0.9765 | val loss 0.8884 mae 1.0013
# epoch 207 | train loss 0.8475 mae 0.9757 | val loss 0.8881 mae 1.0002
# epoch 208 | train loss 0.8486 mae 0.9763 | val loss 0.8879 mae 1.0013
# epoch 209 | train loss 0.8486 mae 0.9760 | val loss 0.8880 mae 1.0004
# epoch 210 | train loss 0.8490 mae 0.9761 | val loss 0.8882 mae 1.0010
# epoch 211 | train loss 0.8491 mae 0.9767 | val loss 0.8890 mae 1.0014
# epoch 212 | train loss 0.8481 mae 0.9756 | val loss 0.8890 mae 0.9994
# epoch 213 | train loss 0.8489 mae 0.9752 | val loss 0.8889 mae 1.0011
# epoch 214 | train loss 0.8490 mae 0.9760 | val loss 0.8879 mae 1.0007
# epoch 215 | train loss 0.8495 mae 0.9767 | val loss 0.8885 mae 1.0024
# epoch 216 | train loss 0.8505 mae 0.9792 | val loss 0.8886 mae 1.0038
# epoch 217 | train loss 0.8503 mae 0.9796 | val loss 0.8886 mae 1.0027
# epoch 218 | train loss 0.8500 mae 0.9784 | val loss 0.8892 mae 1.0014
# epoch 219 | train loss 0.8488 mae 0.9766 | val loss 0.8899 mae 1.0009
# epoch 220 | train loss 0.8489 mae 0.9749 | val loss 0.8904 mae 0.9995
# epoch 221 | train loss 0.8485 mae 0.9753 | val loss 0.8887 mae 1.0014
# epoch 222 | train loss 0.8490 mae 0.9765 | val loss 0.8886 mae 1.0011
# epoch 223 | train loss 0.8489 mae 0.9755 | val loss 0.8886 mae 0.9997
# epoch 224 | train loss 0.8486 mae 0.9760 | val loss 0.8884 mae 1.0021
# epoch 225 | train loss 0.8479 mae 0.9773 | val loss 0.8887 mae 1.0015
# epoch 226 | train loss 0.8483 mae 0.9756 | val loss 0.8891 mae 0.9997
# epoch 227 | train loss 0.8487 mae 0.9735 | val loss 0.8885 mae 0.9990
# epoch 228 | train loss 0.8484 mae 0.9750 | val loss 0.8883 mae 1.0019
# epoch 229 | train loss 0.8481 mae 0.9780 | val loss 0.8890 mae 1.0029
# epoch 230 | train loss 0.8489 mae 0.9772 | val loss 0.8887 mae 1.0004
# epoch 231 | train loss 0.8482 mae 0.9765 | val loss 0.8883 mae 1.0013
# epoch 232 | train loss 0.8484 mae 0.9770 | val loss 0.8884 mae 1.0015
# epoch 233 | train loss 0.8483 mae 0.9754 | val loss 0.8887 mae 0.9990
# epoch 234 | train loss 0.8482 mae 0.9740 | val loss 0.8889 mae 0.9999
# epoch 235 | train loss 0.8491 mae 0.9772 | val loss 0.8891 mae 1.0041
# epoch 236 | train loss 0.8483 mae 0.9778 | val loss 0.8883 mae 1.0001
# epoch 237 | train loss 0.8490 mae 0.9745 | val loss 0.8888 mae 0.9995
# epoch 238 | train loss 0.8486 mae 0.9736 | val loss 0.8887 mae 0.9995
# epoch 239 | train loss 0.8482 mae 0.9765 | val loss 0.8883 mae 1.0031
# epoch 240 | train loss 0.8491 mae 0.9784 | val loss 0.8884 mae 1.0014
# epoch 241 | train loss 0.8482 mae 0.9749 | val loss 0.8879 mae 0.9988
# epoch 242 | train loss 0.8481 mae 0.9749 | val loss 0.8884 mae 1.0014
# epoch 243 | train loss 0.8484 mae 0.9784 | val loss 0.8893 mae 1.0032
# epoch 244 | train loss 0.8482 mae 0.9770 | val loss 0.8890 mae 0.9997
# epoch 245 | train loss 0.8482 mae 0.9741 | val loss 0.8888 mae 0.9992
# epoch 246 | train loss 0.8490 mae 0.9759 | val loss 0.8891 mae 1.0018
# epoch 247 | train loss 0.8492 mae 0.9761 | val loss 0.8892 mae 0.9996
# epoch 248 | train loss 0.8479 mae 0.9754 | val loss 0.8887 mae 1.0012
#
# === Training GIN model with depth=1 ===
# epoch 001 | train loss 0.9983 mae 0.9905 | val loss 0.9665 mae 1.0147
# epoch 002 | train loss 0.8651 mae 1.0218 | val loss 1.0016 mae 0.9927
# epoch 003 | train loss 0.8430 mae 0.9601 | val loss 0.9354 mae 0.9789
# epoch 004 | train loss 0.8143 mae 0.9538 | val loss 0.8517 mae 0.9762
# epoch 005 | train loss 0.8152 mae 0.9650 | val loss 0.8538 mae 0.9751
# epoch 006 | train loss 0.8132 mae 0.9552 | val loss 0.8563 mae 0.9697
# epoch 007 | train loss 0.8061 mae 0.9617 | val loss 0.8314 mae 0.9802
# epoch 008 | train loss 0.8098 mae 0.9638 | val loss 0.8385 mae 0.9719
# epoch 009 | train loss 0.8033 mae 0.9470 | val loss 0.8494 mae 0.9685
# epoch 010 | train loss 0.7970 mae 0.9625 | val loss 0.8253 mae 0.9806
# epoch 011 | train loss 0.7983 mae 0.9576 | val loss 0.8279 mae 0.9754
# epoch 012 | train loss 0.7993 mae 0.9654 | val loss 0.8216 mae 0.9807
# epoch 013 | train loss 0.7941 mae 0.9498 | val loss 0.8312 mae 0.9773
# epoch 014 | train loss 0.7957 mae 0.9530 | val loss 0.8235 mae 0.9793
# epoch 015 | train loss 0.7931 mae 0.9572 | val loss 0.8317 mae 0.9722
# epoch 016 | train loss 0.7912 mae 0.9481 | val loss 0.8253 mae 0.9731
# epoch 017 | train loss 0.7923 mae 0.9602 | val loss 0.8284 mae 0.9734
# epoch 018 | train loss 0.7962 mae 0.9524 | val loss 0.8258 mae 0.9687
# epoch 019 | train loss 0.7939 mae 0.9516 | val loss 0.8251 mae 0.9798
# epoch 020 | train loss 0.7863 mae 0.9611 | val loss 0.8238 mae 0.9777
# epoch 021 | train loss 0.7945 mae 0.9485 | val loss 0.8261 mae 0.9721
# epoch 022 | train loss 0.7942 mae 0.9489 | val loss 0.8300 mae 0.9719
# epoch 023 | train loss 0.7891 mae 0.9604 | val loss 0.8232 mae 0.9732
# epoch 024 | train loss 0.7834 mae 0.9488 | val loss 0.8297 mae 0.9749
# epoch 025 | train loss 0.7903 mae 0.9546 | val loss 0.8252 mae 0.9732
# epoch 026 | train loss 0.7865 mae 0.9500 | val loss 0.8339 mae 0.9702
# epoch 027 | train loss 0.7873 mae 0.9525 | val loss 0.8225 mae 0.9821
# epoch 028 | train loss 0.7929 mae 0.9591 | val loss 0.8283 mae 0.9682
# epoch 029 | train loss 0.7822 mae 0.9419 | val loss 0.8340 mae 0.9671
# epoch 030 | train loss 0.7881 mae 0.9589 | val loss 0.8237 mae 0.9946
# epoch 031 | train loss 0.7858 mae 0.9582 | val loss 0.8327 mae 0.9641
# epoch 032 | train loss 0.7915 mae 0.9376 | val loss 0.8219 mae 0.9726
# epoch 033 | train loss 0.7841 mae 0.9699 | val loss 0.8250 mae 0.9941
# epoch 034 | train loss 0.7840 mae 0.9533 | val loss 0.8299 mae 0.9639
# epoch 035 | train loss 0.7816 mae 0.9394 | val loss 0.8275 mae 0.9726
# epoch 036 | train loss 0.7826 mae 0.9603 | val loss 0.8213 mae 0.9836
# epoch 037 | train loss 0.7772 mae 0.9513 | val loss 0.8328 mae 0.9685
# epoch 038 | train loss 0.7853 mae 0.9496 | val loss 0.8249 mae 0.9773
# epoch 039 | train loss 0.7841 mae 0.9540 | val loss 0.8235 mae 0.9712
# epoch 040 | train loss 0.7803 mae 0.9471 | val loss 0.8229 mae 0.9744
# epoch 041 | train loss 0.7810 mae 0.9552 | val loss 0.8252 mae 0.9732
# epoch 042 | train loss 0.7835 mae 0.9490 | val loss 0.8255 mae 0.9719
# epoch 043 | train loss 0.7830 mae 0.9519 | val loss 0.8215 mae 0.9745
# epoch 044 | train loss 0.7878 mae 0.9542 | val loss 0.8296 mae 0.9674
# epoch 045 | train loss 0.7780 mae 0.9432 | val loss 0.8404 mae 0.9685
# epoch 046 | train loss 0.7862 mae 0.9501 | val loss 0.8220 mae 0.9913
# epoch 047 | train loss 0.7894 mae 0.9653 | val loss 0.8258 mae 0.9701
# epoch 048 | train loss 0.7843 mae 0.9389 | val loss 0.8257 mae 0.9708
# epoch 049 | train loss 0.7845 mae 0.9598 | val loss 0.8333 mae 0.9879
# epoch 050 | train loss 0.7841 mae 0.9568 | val loss 0.8348 mae 0.9630
# epoch 051 | train loss 0.7841 mae 0.9449 | val loss 0.8214 mae 0.9882
# epoch 052 | train loss 0.7821 mae 0.9604 | val loss 0.8299 mae 0.9774
# epoch 053 | train loss 0.7797 mae 0.9442 | val loss 0.8359 mae 0.9636
# epoch 054 | train loss 0.7767 mae 0.9483 | val loss 0.8221 mae 0.9871
# epoch 055 | train loss 0.7794 mae 0.9570 | val loss 0.8252 mae 0.9717
# epoch 056 | train loss 0.7758 mae 0.9475 | val loss 0.8277 mae 0.9678
# epoch 057 | train loss 0.7815 mae 0.9465 | val loss 0.8225 mae 0.9775
# epoch 058 | train loss 0.7761 mae 0.9610 | val loss 0.8288 mae 0.9854
# epoch 059 | train loss 0.7809 mae 0.9488 | val loss 0.8334 mae 0.9645
# epoch 060 | train loss 0.7808 mae 0.9386 | val loss 0.8257 mae 0.9726
# epoch 061 | train loss 0.7871 mae 0.9734 | val loss 0.8294 mae 0.9922
# epoch 062 | train loss 0.7777 mae 0.9509 | val loss 0.8474 mae 0.9632
# epoch 063 | train loss 0.7844 mae 0.9379 | val loss 0.8285 mae 0.9714
# epoch 064 | train loss 0.7779 mae 0.9548 | val loss 0.8189 mae 0.9790
# epoch 065 | train loss 0.7743 mae 0.9547 | val loss 0.8278 mae 0.9764
# epoch 066 | train loss 0.7782 mae 0.9481 | val loss 0.8250 mae 0.9715
# epoch 067 | train loss 0.7756 mae 0.9462 | val loss 0.8296 mae 0.9720
# epoch 068 | train loss 0.7742 mae 0.9579 | val loss 0.8249 mae 0.9822
# epoch 069 | train loss 0.7747 mae 0.9483 | val loss 0.8269 mae 0.9657
# epoch 070 | train loss 0.7722 mae 0.9448 | val loss 0.8282 mae 0.9752
# epoch 071 | train loss 0.7749 mae 0.9526 | val loss 0.8261 mae 0.9788
# epoch 072 | train loss 0.7766 mae 0.9491 | val loss 0.8310 mae 0.9670
# epoch 073 | train loss 0.7714 mae 0.9470 | val loss 0.8216 mae 0.9743
# epoch 074 | train loss 0.7763 mae 0.9505 | val loss 0.8230 mae 0.9759
# epoch 075 | train loss 0.7741 mae 0.9510 | val loss 0.8315 mae 0.9703
# epoch 076 | train loss 0.7733 mae 0.9462 | val loss 0.8235 mae 0.9754
# epoch 077 | train loss 0.7767 mae 0.9476 | val loss 0.8230 mae 0.9798
# epoch 078 | train loss 0.7765 mae 0.9545 | val loss 0.8255 mae 0.9684
# epoch 079 | train loss 0.7773 mae 0.9500 | val loss 0.8279 mae 0.9680
# epoch 080 | train loss 0.7838 mae 0.9380 | val loss 0.8332 mae 0.9725
# epoch 081 | train loss 0.7812 mae 0.9738 | val loss 0.8238 mae 0.9872
# epoch 082 | train loss 0.7751 mae 0.9507 | val loss 0.8278 mae 0.9645
# epoch 083 | train loss 0.7772 mae 0.9401 | val loss 0.8270 mae 0.9831
# epoch 084 | train loss 0.7722 mae 0.9559 | val loss 0.8306 mae 0.9716
# epoch 085 | train loss 0.7737 mae 0.9534 | val loss 0.8224 mae 0.9724
# epoch 086 | train loss 0.7724 mae 0.9497 | val loss 0.8291 mae 0.9737
# epoch 087 | train loss 0.7870 mae 0.9466 | val loss 0.8280 mae 0.9766
# epoch 088 | train loss 0.7727 mae 0.9569 | val loss 0.8230 mae 0.9764
# epoch 089 | train loss 0.7768 mae 0.9498 | val loss 0.8282 mae 0.9646
# epoch 090 | train loss 0.7763 mae 0.9390 | val loss 0.8300 mae 0.9730
# epoch 091 | train loss 0.7747 mae 0.9571 | val loss 0.8245 mae 0.9828
# epoch 092 | train loss 0.7717 mae 0.9541 | val loss 0.8253 mae 0.9678
# epoch 093 | train loss 0.7739 mae 0.9446 | val loss 0.8268 mae 0.9780
# epoch 094 | train loss 0.7752 mae 0.9538 | val loss 0.8290 mae 0.9710
# epoch 095 | train loss 0.7756 mae 0.9463 | val loss 0.8290 mae 0.9661
# epoch 096 | train loss 0.7708 mae 0.9489 | val loss 0.8239 mae 0.9855
# epoch 097 | train loss 0.7717 mae 0.9508 | val loss 0.8273 mae 0.9723
# epoch 098 | train loss 0.7746 mae 0.9488 | val loss 0.8273 mae 0.9695
# epoch 099 | train loss 0.7719 mae 0.9460 | val loss 0.8271 mae 0.9694
# epoch 100 | train loss 0.7756 mae 0.9482 | val loss 0.8261 mae 0.9863
# epoch 101 | train loss 0.7695 mae 0.9541 | val loss 0.8297 mae 0.9669
# epoch 102 | train loss 0.7706 mae 0.9423 | val loss 0.8294 mae 0.9661
# epoch 103 | train loss 0.7691 mae 0.9518 | val loss 0.8228 mae 0.9777
# epoch 104 | train loss 0.7696 mae 0.9540 | val loss 0.8298 mae 0.9669
# epoch 105 | train loss 0.7720 mae 0.9424 | val loss 0.8241 mae 0.9797
# epoch 106 | train loss 0.7722 mae 0.9543 | val loss 0.8254 mae 0.9732
# epoch 107 | train loss 0.7723 mae 0.9452 | val loss 0.8312 mae 0.9654
# epoch 108 | train loss 0.7704 mae 0.9522 | val loss 0.8305 mae 0.9885
# epoch 109 | train loss 0.7693 mae 0.9522 | val loss 0.8300 mae 0.9667
# epoch 110 | train loss 0.7691 mae 0.9426 | val loss 0.8262 mae 0.9706
# epoch 111 | train loss 0.7680 mae 0.9512 | val loss 0.8247 mae 0.9802
# epoch 112 | train loss 0.7653 mae 0.9517 | val loss 0.8293 mae 0.9710
# epoch 113 | train loss 0.7714 mae 0.9444 | val loss 0.8321 mae 0.9663
# epoch 114 | train loss 0.7693 mae 0.9475 | val loss 0.8276 mae 0.9782
# epoch 115 | train loss 0.7687 mae 0.9547 | val loss 0.8214 mae 0.9780
# epoch 116 | train loss 0.7692 mae 0.9484 | val loss 0.8291 mae 0.9695
# epoch 117 | train loss 0.7660 mae 0.9452 | val loss 0.8302 mae 0.9703
# epoch 118 | train loss 0.7664 mae 0.9485 | val loss 0.8269 mae 0.9724
# epoch 119 | train loss 0.7717 mae 0.9522 | val loss 0.8295 mae 0.9734
# epoch 120 | train loss 0.7657 mae 0.9448 | val loss 0.8303 mae 0.9682
# epoch 121 | train loss 0.7689 mae 0.9444 | val loss 0.8263 mae 0.9754
# epoch 122 | train loss 0.7714 mae 0.9634 | val loss 0.8357 mae 0.9760
# epoch 123 | train loss 0.7692 mae 0.9448 | val loss 0.8359 mae 0.9668
# epoch 124 | train loss 0.7736 mae 0.9478 | val loss 0.8275 mae 0.9900
# epoch 125 | train loss 0.7695 mae 0.9613 | val loss 0.8319 mae 0.9686
# epoch 126 | train loss 0.7723 mae 0.9406 | val loss 0.8386 mae 0.9627
# epoch 127 | train loss 0.7822 mae 0.9443 | val loss 0.8308 mae 0.9903
# epoch 128 | train loss 0.7695 mae 0.9704 | val loss 0.8312 mae 0.9906
# epoch 129 | train loss 0.7742 mae 0.9460 | val loss 0.8335 mae 0.9619
# epoch 130 | train loss 0.7712 mae 0.9409 | val loss 0.8301 mae 0.9769
# epoch 131 | train loss 0.7679 mae 0.9611 | val loss 0.8221 mae 0.9774
# epoch 132 | train loss 0.7662 mae 0.9484 | val loss 0.8280 mae 0.9666
# epoch 133 | train loss 0.7666 mae 0.9404 | val loss 0.8312 mae 0.9710
# epoch 134 | train loss 0.7675 mae 0.9517 | val loss 0.8256 mae 0.9778
# epoch 135 | train loss 0.7650 mae 0.9508 | val loss 0.8292 mae 0.9690
# epoch 136 | train loss 0.7660 mae 0.9434 | val loss 0.8290 mae 0.9720
# epoch 137 | train loss 0.7654 mae 0.9476 | val loss 0.8238 mae 0.9744
# epoch 138 | train loss 0.7667 mae 0.9476 | val loss 0.8266 mae 0.9756
# epoch 139 | train loss 0.7678 mae 0.9548 | val loss 0.8261 mae 0.9735
# epoch 140 | train loss 0.7671 mae 0.9456 | val loss 0.8324 mae 0.9664
# epoch 141 | train loss 0.7644 mae 0.9477 | val loss 0.8366 mae 0.9737
# epoch 142 | train loss 0.7667 mae 0.9484 | val loss 0.8292 mae 0.9722
# epoch 143 | train loss 0.7643 mae 0.9484 | val loss 0.8267 mae 0.9731
# epoch 144 | train loss 0.7632 mae 0.9489 | val loss 0.8260 mae 0.9779
# epoch 145 | train loss 0.7684 mae 0.9496 | val loss 0.8275 mae 0.9731
# epoch 146 | train loss 0.7712 mae 0.9546 | val loss 0.8340 mae 0.9748
# epoch 147 | train loss 0.7693 mae 0.9442 | val loss 0.8321 mae 0.9675
# epoch 148 | train loss 0.7647 mae 0.9524 | val loss 0.8244 mae 0.9737
# epoch 149 | train loss 0.7664 mae 0.9504 | val loss 0.8306 mae 0.9701
# epoch 150 | train loss 0.7629 mae 0.9453 | val loss 0.8325 mae 0.9717
# epoch 151 | train loss 0.7681 mae 0.9472 | val loss 0.8315 mae 0.9711
# epoch 152 | train loss 0.7632 mae 0.9495 | val loss 0.8275 mae 0.9739
# epoch 153 | train loss 0.7663 mae 0.9440 | val loss 0.8305 mae 0.9720
# epoch 154 | train loss 0.7646 mae 0.9539 | val loss 0.8328 mae 0.9764
# epoch 155 | train loss 0.7620 mae 0.9449 | val loss 0.8360 mae 0.9644
# epoch 156 | train loss 0.7752 mae 0.9415 | val loss 0.8282 mae 0.9853
# epoch 157 | train loss 0.7795 mae 0.9722 | val loss 0.8400 mae 0.9828
# epoch 158 | train loss 0.7709 mae 0.9427 | val loss 0.8483 mae 0.9623
# epoch 159 | train loss 0.7747 mae 0.9408 | val loss 0.8280 mae 0.9921
# epoch 160 | train loss 0.7712 mae 0.9731 | val loss 0.8298 mae 0.9799
# epoch 161 | train loss 0.7658 mae 0.9453 | val loss 0.8394 mae 0.9622
# epoch 162 | train loss 0.7656 mae 0.9393 | val loss 0.8261 mae 0.9790
# epoch 163 | train loss 0.7671 mae 0.9600 | val loss 0.8306 mae 0.9813
# epoch 164 | train loss 0.7629 mae 0.9515 | val loss 0.8336 mae 0.9662
# epoch 165 | train loss 0.7649 mae 0.9468 | val loss 0.8302 mae 0.9725
# epoch 166 | train loss 0.7629 mae 0.9465 | val loss 0.8310 mae 0.9738
# epoch 167 | train loss 0.7655 mae 0.9537 | val loss 0.8270 mae 0.9810
# epoch 168 | train loss 0.7632 mae 0.9489 | val loss 0.8320 mae 0.9715
# epoch 169 | train loss 0.7634 mae 0.9476 | val loss 0.8311 mae 0.9764
# epoch 170 | train loss 0.7635 mae 0.9516 | val loss 0.8361 mae 0.9666
# epoch 171 | train loss 0.7676 mae 0.9416 | val loss 0.8286 mae 0.9787
# epoch 172 | train loss 0.7631 mae 0.9530 | val loss 0.8332 mae 0.9787
# epoch 173 | train loss 0.7620 mae 0.9487 | val loss 0.8307 mae 0.9664
# epoch 174 | train loss 0.7622 mae 0.9447 | val loss 0.8272 mae 0.9718
# epoch 175 | train loss 0.7636 mae 0.9449 | val loss 0.8309 mae 0.9770
# epoch 176 | train loss 0.7616 mae 0.9535 | val loss 0.8302 mae 0.9735
# epoch 177 | train loss 0.7609 mae 0.9462 | val loss 0.8333 mae 0.9687
# epoch 178 | train loss 0.7630 mae 0.9476 | val loss 0.8310 mae 0.9731
# epoch 179 | train loss 0.7600 mae 0.9485 | val loss 0.8337 mae 0.9687
# epoch 180 | train loss 0.7643 mae 0.9416 | val loss 0.8330 mae 0.9741
# epoch 181 | train loss 0.7640 mae 0.9555 | val loss 0.8294 mae 0.9753
# epoch 182 | train loss 0.7635 mae 0.9476 | val loss 0.8356 mae 0.9684
# epoch 183 | train loss 0.7625 mae 0.9419 | val loss 0.8349 mae 0.9714
# epoch 184 | train loss 0.7620 mae 0.9537 | val loss 0.8287 mae 0.9777
# epoch 185 | train loss 0.7609 mae 0.9471 | val loss 0.8277 mae 0.9715
# epoch 186 | train loss 0.7604 mae 0.9456 | val loss 0.8308 mae 0.9718
# epoch 187 | train loss 0.7579 mae 0.9474 | val loss 0.8370 mae 0.9696
# epoch 188 | train loss 0.7607 mae 0.9472 | val loss 0.8297 mae 0.9792
# epoch 189 | train loss 0.7601 mae 0.9528 | val loss 0.8311 mae 0.9744
# epoch 190 | train loss 0.7619 mae 0.9474 | val loss 0.8347 mae 0.9703
# epoch 191 | train loss 0.7607 mae 0.9455 | val loss 0.8346 mae 0.9702
# epoch 192 | train loss 0.7632 mae 0.9465 | val loss 0.8258 mae 0.9775
# epoch 193 | train loss 0.7599 mae 0.9541 | val loss 0.8328 mae 0.9694
# epoch 194 | train loss 0.7625 mae 0.9418 | val loss 0.8347 mae 0.9682
# epoch 195 | train loss 0.7647 mae 0.9473 | val loss 0.8361 mae 0.9782
# epoch 196 | train loss 0.7585 mae 0.9540 | val loss 0.8332 mae 0.9727
# epoch 197 | train loss 0.7646 mae 0.9487 | val loss 0.8289 mae 0.9694
# epoch 198 | train loss 0.7614 mae 0.9401 | val loss 0.8371 mae 0.9760
# epoch 199 | train loss 0.7634 mae 0.9529 | val loss 0.8341 mae 0.9786
# epoch 200 | train loss 0.7640 mae 0.9514 | val loss 0.8303 mae 0.9664
# epoch 201 | train loss 0.7603 mae 0.9421 | val loss 0.8325 mae 0.9727
# epoch 202 | train loss 0.7635 mae 0.9526 | val loss 0.8349 mae 0.9756
# epoch 203 | train loss 0.7643 mae 0.9500 | val loss 0.8285 mae 0.9717
# epoch 204 | train loss 0.7610 mae 0.9477 | val loss 0.8297 mae 0.9756
# epoch 205 | train loss 0.7615 mae 0.9469 | val loss 0.8289 mae 0.9701
# epoch 206 | train loss 0.7604 mae 0.9452 | val loss 0.8305 mae 0.9706
# epoch 207 | train loss 0.7607 mae 0.9535 | val loss 0.8378 mae 0.9743
# epoch 208 | train loss 0.7599 mae 0.9448 | val loss 0.8407 mae 0.9662
# epoch 209 | train loss 0.7656 mae 0.9437 | val loss 0.8265 mae 0.9824
# epoch 210 | train loss 0.7682 mae 0.9594 | val loss 0.8365 mae 0.9773
# epoch 211 | train loss 0.7631 mae 0.9410 | val loss 0.8509 mae 0.9648
# epoch 212 | train loss 0.7609 mae 0.9454 | val loss 0.8311 mae 0.9821
# epoch 213 | train loss 0.7623 mae 0.9582 | val loss 0.8280 mae 0.9770
# epoch 214 | train loss 0.7611 mae 0.9444 | val loss 0.8348 mae 0.9688
# epoch 215 | train loss 0.7587 mae 0.9493 | val loss 0.8290 mae 0.9730
# epoch 216 | train loss 0.7597 mae 0.9471 | val loss 0.8350 mae 0.9671
# epoch 217 | train loss 0.7654 mae 0.9402 | val loss 0.8353 mae 0.9776
# epoch 218 | train loss 0.7651 mae 0.9643 | val loss 0.8388 mae 0.9799
# epoch 219 | train loss 0.7581 mae 0.9456 | val loss 0.8426 mae 0.9637
# epoch 220 | train loss 0.7649 mae 0.9386 | val loss 0.8302 mae 0.9810
# epoch 221 | train loss 0.7702 mae 0.9682 | val loss 0.8362 mae 0.9801
# epoch 222 | train loss 0.7613 mae 0.9432 | val loss 0.8416 mae 0.9634
# epoch 223 | train loss 0.7592 mae 0.9411 | val loss 0.8256 mae 0.9787
# epoch 224 | train loss 0.7609 mae 0.9606 | val loss 0.8287 mae 0.9751
# epoch 225 | train loss 0.7580 mae 0.9445 | val loss 0.8422 mae 0.9655
# epoch 226 | train loss 0.7595 mae 0.9422 | val loss 0.8317 mae 0.9792
# epoch 227 | train loss 0.7585 mae 0.9523 | val loss 0.8313 mae 0.9755
# epoch 228 | train loss 0.7589 mae 0.9479 | val loss 0.8334 mae 0.9703
# epoch 229 | train loss 0.7587 mae 0.9451 | val loss 0.8313 mae 0.9751
#
# === Training GIN model with depth=2 ===
# epoch 001 | train loss 0.9889 mae 1.0211 | val loss 1.0786 mae 1.0031
# epoch 002 | train loss 0.8176 mae 0.9537 | val loss 0.8855 mae 0.9915
# epoch 003 | train loss 0.7979 mae 0.9579 | val loss 0.9284 mae 0.9711
# epoch 004 | train loss 0.8007 mae 0.9623 | val loss 0.8123 mae 0.9640
# epoch 005 | train loss 0.7841 mae 0.9426 | val loss 0.8027 mae 0.9708
# epoch 006 | train loss 0.7850 mae 0.9582 | val loss 0.7986 mae 0.9582
# epoch 007 | train loss 0.7683 mae 0.9371 | val loss 0.8207 mae 0.9617
# epoch 008 | train loss 0.7809 mae 0.9593 | val loss 0.7947 mae 1.0132
# epoch 009 | train loss 0.7688 mae 0.9536 | val loss 0.8067 mae 0.9563
# epoch 010 | train loss 0.7613 mae 0.9335 | val loss 0.7944 mae 0.9615
# epoch 011 | train loss 0.7488 mae 0.9462 | val loss 0.7909 mae 0.9717
# epoch 012 | train loss 0.7471 mae 0.9437 | val loss 0.7912 mae 0.9559
# epoch 013 | train loss 0.7423 mae 0.9384 | val loss 0.7915 mae 0.9628
# epoch 014 | train loss 0.7575 mae 0.9391 | val loss 0.8119 mae 1.0303
# epoch 015 | train loss 0.7573 mae 0.9529 | val loss 0.8247 mae 0.9544
# epoch 016 | train loss 0.7518 mae 0.9364 | val loss 0.8034 mae 0.9720
# epoch 017 | train loss 0.7653 mae 0.9541 | val loss 0.8156 mae 0.9591
# epoch 018 | train loss 0.7506 mae 0.9466 | val loss 0.7836 mae 0.9704
# epoch 019 | train loss 0.7416 mae 0.9335 | val loss 0.8252 mae 0.9562
# epoch 020 | train loss 0.7388 mae 0.9318 | val loss 0.7875 mae 0.9851
# epoch 021 | train loss 0.7437 mae 0.9488 | val loss 0.7868 mae 0.9532
# epoch 022 | train loss 0.7327 mae 0.9357 | val loss 0.7706 mae 0.9601
# epoch 023 | train loss 0.7252 mae 0.9371 | val loss 0.7925 mae 0.9595
# epoch 024 | train loss 0.7245 mae 0.9327 | val loss 0.7824 mae 0.9513
# epoch 025 | train loss 0.7330 mae 0.9419 | val loss 0.7672 mae 0.9722
# epoch 026 | train loss 0.7374 mae 0.9363 | val loss 0.7956 mae 0.9456
# epoch 027 | train loss 0.7309 mae 0.9331 | val loss 0.7963 mae 0.9616
# epoch 028 | train loss 0.7226 mae 0.9391 | val loss 0.7672 mae 0.9502
# epoch 029 | train loss 0.7182 mae 0.9318 | val loss 0.7841 mae 0.9606
# epoch 030 | train loss 0.7237 mae 0.9367 | val loss 0.7809 mae 0.9616
# epoch 031 | train loss 0.7307 mae 0.9323 | val loss 0.7652 mae 0.9667
# epoch 032 | train loss 0.7219 mae 0.9335 | val loss 0.7965 mae 0.9616
# epoch 033 | train loss 0.7328 mae 0.9362 | val loss 0.7847 mae 0.9854
# epoch 034 | train loss 0.7381 mae 0.9473 | val loss 0.7840 mae 0.9499
# epoch 035 | train loss 0.7363 mae 0.9273 | val loss 0.7949 mae 0.9732
# epoch 036 | train loss 0.7234 mae 0.9438 | val loss 0.7683 mae 0.9502
# epoch 037 | train loss 0.7178 mae 0.9291 | val loss 0.7887 mae 0.9567
# epoch 038 | train loss 0.7146 mae 0.9368 | val loss 0.7708 mae 0.9518
# epoch 039 | train loss 0.7171 mae 0.9254 | val loss 0.7699 mae 0.9580
# epoch 040 | train loss 0.7186 mae 0.9319 | val loss 0.7735 mae 0.9871
# epoch 041 | train loss 0.7284 mae 0.9411 | val loss 0.8180 mae 0.9489
# epoch 042 | train loss 0.7261 mae 0.9369 | val loss 0.7729 mae 0.9888
# epoch 043 | train loss 0.7280 mae 0.9370 | val loss 0.7742 mae 0.9499
# epoch 044 | train loss 0.7297 mae 0.9348 | val loss 0.7845 mae 0.9457
# epoch 045 | train loss 0.7191 mae 0.9250 | val loss 0.8301 mae 0.9485
# epoch 046 | train loss 0.7168 mae 0.9351 | val loss 0.7701 mae 0.9699
# epoch 047 | train loss 0.7189 mae 0.9440 | val loss 0.7851 mae 0.9462
# epoch 048 | train loss 0.7127 mae 0.9185 | val loss 0.7907 mae 0.9644
# epoch 049 | train loss 0.7097 mae 0.9463 | val loss 0.7706 mae 0.9656
# epoch 050 | train loss 0.7113 mae 0.9297 | val loss 0.7802 mae 0.9499
# epoch 051 | train loss 0.7081 mae 0.9272 | val loss 0.7773 mae 0.9476
# epoch 052 | train loss 0.7064 mae 0.9299 | val loss 0.7809 mae 0.9504
# epoch 053 | train loss 0.7045 mae 0.9310 | val loss 0.7901 mae 0.9467
# epoch 054 | train loss 0.7011 mae 0.9279 | val loss 0.7690 mae 0.9623
# epoch 055 | train loss 0.7032 mae 0.9324 | val loss 0.7702 mae 0.9533
# epoch 056 | train loss 0.7022 mae 0.9258 | val loss 0.7677 mae 0.9517
# epoch 057 | train loss 0.7060 mae 0.9261 | val loss 0.7823 mae 0.9452
# epoch 058 | train loss 0.7020 mae 0.9315 | val loss 0.7835 mae 0.9642
# epoch 059 | train loss 0.6980 mae 0.9234 | val loss 0.7786 mae 0.9506
# epoch 060 | train loss 0.6997 mae 0.9260 | val loss 0.7655 mae 0.9592
# epoch 061 | train loss 0.6957 mae 0.9338 | val loss 0.7858 mae 0.9551
# epoch 062 | train loss 0.6957 mae 0.9230 | val loss 0.7718 mae 0.9508
# epoch 063 | train loss 0.6950 mae 0.9288 | val loss 0.7914 mae 0.9438
# epoch 064 | train loss 0.7018 mae 0.9242 | val loss 0.7919 mae 1.0161
# epoch 065 | train loss 0.7039 mae 0.9430 | val loss 0.7955 mae 0.9490
# epoch 066 | train loss 0.6975 mae 0.9162 | val loss 0.7795 mae 0.9636
# epoch 067 | train loss 0.7025 mae 0.9345 | val loss 0.7874 mae 0.9729
# epoch 068 | train loss 0.6951 mae 0.9308 | val loss 0.7747 mae 0.9438
# epoch 069 | train loss 0.6933 mae 0.9202 | val loss 0.7904 mae 0.9522
# epoch 070 | train loss 0.7009 mae 0.9381 | val loss 0.7869 mae 0.9473
# epoch 071 | train loss 0.7021 mae 0.9168 | val loss 0.8137 mae 0.9956
# epoch 072 | train loss 0.7002 mae 0.9444 | val loss 0.7669 mae 0.9467
# epoch 073 | train loss 0.7004 mae 0.9200 | val loss 0.7991 mae 0.9581
# epoch 074 | train loss 0.6938 mae 0.9278 | val loss 0.7940 mae 0.9443
# epoch 075 | train loss 0.6941 mae 0.9250 | val loss 0.7963 mae 0.9741
# epoch 076 | train loss 0.7009 mae 0.9280 | val loss 0.7821 mae 0.9555
# epoch 077 | train loss 0.6956 mae 0.9298 | val loss 0.7840 mae 0.9395
# epoch 078 | train loss 0.6888 mae 0.9194 | val loss 0.7918 mae 0.9590
# epoch 079 | train loss 0.6952 mae 0.9324 | val loss 0.7809 mae 0.9483
# epoch 080 | train loss 0.6904 mae 0.9254 | val loss 0.7774 mae 0.9501
# epoch 081 | train loss 0.6871 mae 0.9186 | val loss 0.7852 mae 0.9608
# epoch 082 | train loss 0.6870 mae 0.9295 | val loss 0.7780 mae 0.9475
# epoch 083 | train loss 0.6847 mae 0.9233 | val loss 0.7775 mae 0.9582
# epoch 084 | train loss 0.6882 mae 0.9262 | val loss 0.8026 mae 0.9447
# epoch 085 | train loss 0.6868 mae 0.9213 | val loss 0.7773 mae 0.9520
# epoch 086 | train loss 0.6894 mae 0.9284 | val loss 0.8073 mae 0.9716
# epoch 087 | train loss 0.6898 mae 0.9264 | val loss 0.7843 mae 0.9417
# epoch 088 | train loss 0.6885 mae 0.9204 | val loss 0.7948 mae 0.9537
# epoch 089 | train loss 0.6837 mae 0.9333 | val loss 0.8062 mae 0.9410
# epoch 090 | train loss 0.6858 mae 0.9202 | val loss 0.7751 mae 0.9667
# epoch 091 | train loss 0.6886 mae 0.9277 | val loss 0.7893 mae 0.9497
# epoch 092 | train loss 0.6843 mae 0.9209 | val loss 0.7752 mae 0.9478
# epoch 093 | train loss 0.6818 mae 0.9207 | val loss 0.7915 mae 0.9566
# epoch 094 | train loss 0.6831 mae 0.9330 | val loss 0.7821 mae 0.9414
# epoch 095 | train loss 0.6832 mae 0.9171 | val loss 0.7988 mae 0.9699
# epoch 096 | train loss 0.6814 mae 0.9291 | val loss 0.7807 mae 0.9486
# epoch 097 | train loss 0.6832 mae 0.9170 | val loss 0.7980 mae 0.9458
# epoch 098 | train loss 0.6805 mae 0.9310 | val loss 0.7942 mae 0.9492
# epoch 099 | train loss 0.6818 mae 0.9194 | val loss 0.7863 mae 0.9540
# epoch 100 | train loss 0.6809 mae 0.9270 | val loss 0.7867 mae 0.9401
# epoch 101 | train loss 0.6804 mae 0.9217 | val loss 0.7908 mae 0.9594
# epoch 102 | train loss 0.6798 mae 0.9276 | val loss 0.7922 mae 0.9466
# epoch 103 | train loss 0.6816 mae 0.9128 | val loss 0.8022 mae 0.9668
# epoch 104 | train loss 0.6816 mae 0.9285 | val loss 0.7832 mae 0.9457
# epoch 105 | train loss 0.6805 mae 0.9217 | val loss 0.7955 mae 0.9552
# epoch 106 | train loss 0.6854 mae 0.9208 | val loss 0.7974 mae 0.9528
# epoch 107 | train loss 0.6908 mae 0.9292 | val loss 0.7832 mae 0.9568
# epoch 108 | train loss 0.7081 mae 0.9200 | val loss 0.8126 mae 0.9509
# epoch 109 | train loss 0.7030 mae 0.9418 | val loss 0.8058 mae 0.9472
# epoch 110 | train loss 0.6888 mae 0.9219 | val loss 0.7993 mae 0.9548
# epoch 111 | train loss 0.6970 mae 0.9242 | val loss 0.7826 mae 0.9565
# epoch 112 | train loss 0.7015 mae 0.9309 | val loss 0.8176 mae 0.9426
# epoch 113 | train loss 0.6837 mae 0.9167 | val loss 0.7762 mae 0.9617
# epoch 114 | train loss 0.6822 mae 0.9343 | val loss 0.7655 mae 0.9495
# epoch 115 | train loss 0.6844 mae 0.9224 | val loss 0.7866 mae 0.9457
# epoch 116 | train loss 0.6808 mae 0.9147 | val loss 0.8164 mae 0.9637
# epoch 117 | train loss 0.6841 mae 0.9354 | val loss 0.7867 mae 0.9627
# epoch 118 | train loss 0.6867 mae 0.9214 | val loss 0.7966 mae 0.9407
# epoch 119 | train loss 0.6812 mae 0.9190 | val loss 0.7797 mae 0.9514
# epoch 120 | train loss 0.6814 mae 0.9178 | val loss 0.7974 mae 0.9507
# epoch 121 | train loss 0.6752 mae 0.9253 | val loss 0.7827 mae 0.9487
# epoch 122 | train loss 0.6722 mae 0.9204 | val loss 0.7894 mae 0.9510
# epoch 123 | train loss 0.6711 mae 0.9224 | val loss 0.7836 mae 0.9478
# epoch 124 | train loss 0.6718 mae 0.9192 | val loss 0.8038 mae 0.9427
# epoch 125 | train loss 0.6783 mae 0.9192 | val loss 0.8158 mae 0.9719
# epoch 126 | train loss 0.6773 mae 0.9317 | val loss 0.7949 mae 0.9429
# epoch 127 | train loss 0.6729 mae 0.9128 | val loss 0.8044 mae 0.9655
# epoch 128 | train loss 0.6684 mae 0.9264 | val loss 0.7923 mae 0.9408
# epoch 129 | train loss 0.6736 mae 0.9143 | val loss 0.7843 mae 0.9500
# epoch 130 | train loss 0.6750 mae 0.9229 | val loss 0.7848 mae 0.9557
# epoch 131 | train loss 0.6752 mae 0.9243 | val loss 0.7897 mae 0.9437
# epoch 132 | train loss 0.6786 mae 0.9122 | val loss 0.8067 mae 1.0162
# epoch 133 | train loss 0.6985 mae 0.9686 | val loss 0.8049 mae 0.9485
# epoch 134 | train loss 0.6881 mae 0.9108 | val loss 0.7991 mae 0.9477
# epoch 135 | train loss 0.6805 mae 0.9244 | val loss 0.7712 mae 0.9572
# epoch 136 | train loss 0.6762 mae 0.9238 | val loss 0.8076 mae 0.9422
# epoch 137 | train loss 0.6819 mae 0.9254 | val loss 0.7988 mae 0.9487
# epoch 138 | train loss 0.6884 mae 0.9219 | val loss 0.8042 mae 0.9511
# epoch 139 | train loss 0.6789 mae 0.9249 | val loss 0.7840 mae 0.9460
# epoch 140 | train loss 0.6763 mae 0.9180 | val loss 0.7943 mae 0.9460
# epoch 141 | train loss 0.6763 mae 0.9239 | val loss 0.8043 mae 0.9526
# epoch 142 | train loss 0.6748 mae 0.9226 | val loss 0.7827 mae 0.9451
# epoch 143 | train loss 0.6701 mae 0.9215 | val loss 0.7938 mae 0.9466
# epoch 144 | train loss 0.6666 mae 0.9143 | val loss 0.8060 mae 0.9426
# epoch 145 | train loss 0.6677 mae 0.9227 | val loss 0.7887 mae 0.9528
# epoch 146 | train loss 0.6688 mae 0.9177 | val loss 0.7924 mae 0.9457
# epoch 147 | train loss 0.6686 mae 0.9191 | val loss 0.8032 mae 0.9538
# epoch 148 | train loss 0.6693 mae 0.9168 | val loss 0.8035 mae 0.9482
# epoch 149 | train loss 0.6675 mae 0.9209 | val loss 0.7854 mae 0.9478
# epoch 150 | train loss 0.6650 mae 0.9189 | val loss 0.8048 mae 0.9472
# epoch 151 | train loss 0.6657 mae 0.9162 | val loss 0.8026 mae 0.9544
# epoch 152 | train loss 0.6643 mae 0.9178 | val loss 0.7776 mae 0.9515
# epoch 153 | train loss 0.6665 mae 0.9208 | val loss 0.7953 mae 0.9562
# epoch 154 | train loss 0.6656 mae 0.9208 | val loss 0.7928 mae 0.9439
# epoch 155 | train loss 0.6636 mae 0.9145 | val loss 0.7914 mae 0.9514
# epoch 156 | train loss 0.6623 mae 0.9180 | val loss 0.7984 mae 0.9533
# epoch 157 | train loss 0.6625 mae 0.9209 | val loss 0.7913 mae 0.9450
# epoch 158 | train loss 0.6627 mae 0.9167 | val loss 0.8157 mae 0.9566
# epoch 159 | train loss 0.6668 mae 0.9199 | val loss 0.8018 mae 0.9484
# epoch 160 | train loss 0.6637 mae 0.9129 | val loss 0.8015 mae 0.9539
# epoch 161 | train loss 0.6666 mae 0.9189 | val loss 0.7846 mae 0.9485
# epoch 162 | train loss 0.6743 mae 0.9295 | val loss 0.7883 mae 0.9506
# epoch 163 | train loss 0.6728 mae 0.9109 | val loss 0.8294 mae 0.9476
# epoch 164 | train loss 0.6751 mae 0.9276 | val loss 0.7905 mae 0.9683
# epoch 165 | train loss 0.6645 mae 0.9167 | val loss 0.8174 mae 0.9391
# epoch 166 | train loss 0.6611 mae 0.9152 | val loss 0.8176 mae 0.9455
# epoch 167 | train loss 0.6604 mae 0.9151 | val loss 0.7926 mae 0.9501
# epoch 168 | train loss 0.6684 mae 0.9222 | val loss 0.8045 mae 0.9444
# epoch 169 | train loss 0.6712 mae 0.9167 | val loss 0.8040 mae 0.9632
# epoch 170 | train loss 0.6627 mae 0.9193 | val loss 0.7966 mae 0.9398
# epoch 171 | train loss 0.6569 mae 0.9083 | val loss 0.7899 mae 0.9489
# epoch 172 | train loss 0.6659 mae 0.9254 | val loss 0.8121 mae 0.9456
# epoch 173 | train loss 0.6596 mae 0.9124 | val loss 0.8052 mae 0.9413
# epoch 174 | train loss 0.6569 mae 0.9127 | val loss 0.7950 mae 0.9544
# epoch 175 | train loss 0.6606 mae 0.9219 | val loss 0.7954 mae 0.9471
# epoch 176 | train loss 0.6644 mae 0.9144 | val loss 0.8119 mae 0.9408
# epoch 177 | train loss 0.6577 mae 0.9115 | val loss 0.7949 mae 0.9611
# epoch 178 | train loss 0.6632 mae 0.9180 | val loss 0.7995 mae 0.9493
# epoch 179 | train loss 0.6617 mae 0.9183 | val loss 0.8146 mae 0.9483
# epoch 180 | train loss 0.6628 mae 0.9104 | val loss 0.8120 mae 0.9576
# epoch 181 | train loss 0.6584 mae 0.9231 | val loss 0.8061 mae 0.9426
# epoch 182 | train loss 0.6551 mae 0.9122 | val loss 0.8074 mae 0.9452
# epoch 183 | train loss 0.6538 mae 0.9148 | val loss 0.7960 mae 0.9483
# epoch 184 | train loss 0.6611 mae 0.9214 | val loss 0.7887 mae 0.9474
# epoch 185 | train loss 0.6648 mae 0.9147 | val loss 0.8090 mae 0.9657
# epoch 186 | train loss 0.6586 mae 0.9177 | val loss 0.8092 mae 0.9444
# epoch 187 | train loss 0.6595 mae 0.9169 | val loss 0.7957 mae 0.9576
# epoch 188 | train loss 0.6601 mae 0.9168 | val loss 0.8140 mae 0.9399
# epoch 189 | train loss 0.6530 mae 0.9141 | val loss 0.8240 mae 0.9500
# epoch 190 | train loss 0.6519 mae 0.9159 | val loss 0.8070 mae 0.9423
# epoch 191 | train loss 0.6529 mae 0.9079 | val loss 0.7986 mae 0.9566
# epoch 192 | train loss 0.6512 mae 0.9192 | val loss 0.8074 mae 0.9386
# epoch 193 | train loss 0.6577 mae 0.9151 | val loss 0.8178 mae 0.9523
# epoch 194 | train loss 0.6557 mae 0.9149 | val loss 0.8036 mae 0.9491
# epoch 195 | train loss 0.6578 mae 0.9174 | val loss 0.8200 mae 0.9625
# epoch 196 | train loss 0.6560 mae 0.9172 | val loss 0.7964 mae 0.9511
# epoch 197 | train loss 0.6495 mae 0.9126 | val loss 0.7905 mae 0.9514
# epoch 198 | train loss 0.6535 mae 0.9203 | val loss 0.8314 mae 0.9393
# epoch 199 | train loss 0.6662 mae 0.9106 | val loss 0.8116 mae 0.9528
# epoch 200 | train loss 0.6528 mae 0.9179 | val loss 0.7898 mae 0.9432
# epoch 201 | train loss 0.6498 mae 0.9091 | val loss 0.8021 mae 0.9598
# epoch 202 | train loss 0.6516 mae 0.9153 | val loss 0.8120 mae 0.9489
# epoch 203 | train loss 0.6534 mae 0.9169 | val loss 0.8107 mae 0.9403
# epoch 204 | train loss 0.6545 mae 0.9081 | val loss 0.8096 mae 0.9533
# epoch 205 | train loss 0.6542 mae 0.9180 | val loss 0.8257 mae 0.9440
# epoch 206 | train loss 0.6540 mae 0.9119 | val loss 0.8119 mae 0.9834
# ...
# epoch 384 | train loss 0.4721 mae 0.7991 | val loss 0.5882 mae 0.8358
# epoch 385 | train loss 0.4701 mae 0.7966 | val loss 0.5903 mae 0.8338
# epoch 386 | train loss 0.4710 mae 0.7967 | val loss 0.5832 mae 0.8383
# epoch 387 | train loss 0.4706 mae 0.7948 | val loss 0.5877 mae 0.8266
# epoch 388 | train loss 0.4784 mae 0.8009 | val loss 0.5796 mae 0.8457
# epoch 389 | train loss 0.4782 mae 0.8005 | val loss 0.6079 mae 0.8329
# epoch 390 | train loss 0.4746 mae 0.7983 | val loss 0.5840 mae 0.8353
# epoch 391 | train loss 0.4724 mae 0.7976 | val loss 0.5928 mae 0.8432
# epoch 392 | train loss 0.4758 mae 0.7998 | val loss 0.5943 mae 0.8260
# epoch 393 | train loss 0.4723 mae 0.7931 | val loss 0.5876 mae 0.8269
# epoch 394 | train loss 0.4715 mae 0.8019 | val loss 0.5948 mae 0.8294
# epoch 395 | train loss 0.4730 mae 0.7953 | val loss 0.5832 mae 0.8383
# epoch 396 | train loss 0.4729 mae 0.7989 | val loss 0.5816 mae 0.8344
# epoch 397 | train loss 0.4731 mae 0.7956 | val loss 0.5845 mae 0.8324
# epoch 398 | train loss 0.4716 mae 0.7947 | val loss 0.5909 mae 0.8351
# epoch 399 | train loss 0.4710 mae 0.7969 | val loss 0.5927 mae 0.8307
# epoch 400 | train loss 0.4717 mae 0.7961 | val loss 0.5823 mae 0.8326
# epoch 401 | train loss 0.4691 mae 0.7923 | val loss 0.5848 mae 0.8261
# epoch 402 | train loss 0.4697 mae 0.7956 | val loss 0.5962 mae 0.8268
# epoch 403 | train loss 0.4701 mae 0.7935 | val loss 0.5836 mae 0.8342
# epoch 404 | train loss 0.4697 mae 0.7941 | val loss 0.5886 mae 0.8306
# epoch 405 | train loss 0.4699 mae 0.7981 | val loss 0.5939 mae 0.8361
# epoch 406 | train loss 0.4689 mae 0.7927 | val loss 0.5909 mae 0.8292
# epoch 407 | train loss 0.4697 mae 0.7949 | val loss 0.5832 mae 0.8336
# epoch 408 | train loss 0.4680 mae 0.7943 | val loss 0.5926 mae 0.8344
# epoch 409 | train loss 0.4704 mae 0.7928 | val loss 0.5952 mae 0.8257
# epoch 410 | train loss 0.4738 mae 0.8007 | val loss 0.5792 mae 0.8406
# epoch 411 | train loss 0.4724 mae 0.7929 | val loss 0.5995 mae 0.8317
# epoch 412 | train loss 0.4698 mae 0.7979 | val loss 0.5893 mae 0.8292
# epoch 413 | train loss 0.4726 mae 0.7943 | val loss 0.5979 mae 0.8334
# epoch 414 | train loss 0.4700 mae 0.7975 | val loss 0.5873 mae 0.8384
# epoch 415 | train loss 0.4699 mae 0.7951 | val loss 0.5889 mae 0.8323
# epoch 416 | train loss 0.4684 mae 0.7933 | val loss 0.5791 mae 0.8282
# epoch 417 | train loss 0.4677 mae 0.7938 | val loss 0.5833 mae 0.8335
# epoch 418 | train loss 0.4693 mae 0.7940 | val loss 0.5958 mae 0.8315
# epoch 419 | train loss 0.4685 mae 0.7945 | val loss 0.5877 mae 0.8381
# epoch 420 | train loss 0.4700 mae 0.7934 | val loss 0.6045 mae 0.8283
# epoch 421 | train loss 0.4708 mae 0.7955 | val loss 0.5846 mae 0.8339
# epoch 422 | train loss 0.4709 mae 0.7953 | val loss 0.5895 mae 0.8265
# epoch 423 | train loss 0.4716 mae 0.7981 | val loss 0.5860 mae 0.8456
# epoch 424 | train loss 0.4700 mae 0.7928 | val loss 0.6261 mae 0.8328
# epoch 425 | train loss 0.4693 mae 0.7946 | val loss 0.5905 mae 0.8285
# epoch 426 | train loss 0.4691 mae 0.7997 | val loss 0.5880 mae 0.8359
# epoch 427 | train loss 0.4708 mae 0.7948 | val loss 0.5794 mae 0.8358
# epoch 428 | train loss 0.4690 mae 0.7938 | val loss 0.5997 mae 0.8244
# epoch 429 | train loss 0.4683 mae 0.7937 | val loss 0.5924 mae 0.8352
# epoch 430 | train loss 0.4668 mae 0.7954 | val loss 0.5861 mae 0.8399
# epoch 431 | train loss 0.4694 mae 0.7933 | val loss 0.5968 mae 0.8278
# epoch 432 | train loss 0.4677 mae 0.7928 | val loss 0.5794 mae 0.8282
# epoch 433 | train loss 0.4684 mae 0.7943 | val loss 0.5896 mae 0.8320
# epoch 434 | train loss 0.4667 mae 0.7941 | val loss 0.5909 mae 0.8298
# epoch 435 | train loss 0.4681 mae 0.7928 | val loss 0.5963 mae 0.8283
# epoch 436 | train loss 0.4681 mae 0.7945 | val loss 0.5944 mae 0.8335
# epoch 437 | train loss 0.4686 mae 0.7953 | val loss 0.5838 mae 0.8364
# epoch 438 | train loss 0.4669 mae 0.7924 | val loss 0.5925 mae 0.8287
# epoch 439 | train loss 0.4663 mae 0.7909 | val loss 0.5911 mae 0.8307
# epoch 440 | train loss 0.4699 mae 0.7968 | val loss 0.5833 mae 0.8357
# epoch 441 | train loss 0.4675 mae 0.7937 | val loss 0.6008 mae 0.8303
# epoch 442 | train loss 0.4700 mae 0.7919 | val loss 0.5841 mae 0.8302
# epoch 443 | train loss 0.4772 mae 0.8005 | val loss 0.5837 mae 0.8380
# epoch 444 | train loss 0.4744 mae 0.7955 | val loss 0.6349 mae 0.8467
# epoch 445 | train loss 0.4744 mae 0.8046 | val loss 0.5756 mae 0.8421
# epoch 446 | train loss 0.4689 mae 0.7945 | val loss 0.5991 mae 0.8256
# epoch 447 | train loss 0.4714 mae 0.7973 | val loss 0.5991 mae 0.8492
# epoch 448 | train loss 0.4693 mae 0.7936 | val loss 0.5949 mae 0.8295
# epoch 449 | train loss 0.4679 mae 0.7949 | val loss 0.6000 mae 0.8335
# epoch 450 | train loss 0.4646 mae 0.7919 | val loss 0.5935 mae 0.8273
# epoch 451 | train loss 0.4664 mae 0.7919 | val loss 0.6008 mae 0.8279
# epoch 452 | train loss 0.4655 mae 0.7934 | val loss 0.5858 mae 0.8388
# epoch 453 | train loss 0.4672 mae 0.7942 | val loss 0.5955 mae 0.8337
# epoch 454 | train loss 0.4664 mae 0.7916 | val loss 0.6037 mae 0.8285
# epoch 455 | train loss 0.4667 mae 0.7944 | val loss 0.5935 mae 0.8322
# epoch 456 | train loss 0.4680 mae 0.7922 | val loss 0.5984 mae 0.8277
# epoch 457 | train loss 0.4649 mae 0.7938 | val loss 0.5918 mae 0.8369
# epoch 458 | train loss 0.4680 mae 0.7938 | val loss 0.5891 mae 0.8373
# epoch 459 | train loss 0.4661 mae 0.7918 | val loss 0.5940 mae 0.8331
# epoch 460 | train loss 0.4670 mae 0.7914 | val loss 0.5808 mae 0.8302
# epoch 461 | train loss 0.4709 mae 0.7981 | val loss 0.5850 mae 0.8345
# epoch 462 | train loss 0.4673 mae 0.7919 | val loss 0.5972 mae 0.8301
# epoch 463 | train loss 0.4665 mae 0.7941 | val loss 0.5868 mae 0.8420
# epoch 464 | train loss 0.4662 mae 0.7935 | val loss 0.6030 mae 0.8287
# epoch 465 | train loss 0.4663 mae 0.7945 | val loss 0.5863 mae 0.8325
# epoch 466 | train loss 0.4641 mae 0.7913 | val loss 0.5889 mae 0.8372
# epoch 467 | train loss 0.4679 mae 0.7968 | val loss 0.5935 mae 0.8296
# epoch 468 | train loss 0.4670 mae 0.7915 | val loss 0.5941 mae 0.8276
# epoch 469 | train loss 0.4662 mae 0.7962 | val loss 0.5868 mae 0.8372
# epoch 470 | train loss 0.4671 mae 0.7927 | val loss 0.5967 mae 0.8334
# epoch 471 | train loss 0.4673 mae 0.7957 | val loss 0.5896 mae 0.8280
# epoch 472 | train loss 0.4661 mae 0.7933 | val loss 0.5883 mae 0.8358
# epoch 473 | train loss 0.4680 mae 0.7915 | val loss 0.6038 mae 0.8275
# epoch 474 | train loss 0.4694 mae 0.7961 | val loss 0.5894 mae 0.8459
# epoch 475 | train loss 0.4681 mae 0.7969 | val loss 0.5971 mae 0.8272
# epoch 476 | train loss 0.4693 mae 0.7958 | val loss 0.5847 mae 0.8267
# epoch 477 | train loss 0.4644 mae 0.7904 | val loss 0.6040 mae 0.8359
# epoch 478 | train loss 0.4666 mae 0.7938 | val loss 0.5999 mae 0.8314
# epoch 479 | train loss 0.4658 mae 0.7913 | val loss 0.5857 mae 0.8278
# epoch 480 | train loss 0.4649 mae 0.7925 | val loss 0.6019 mae 0.8264
# epoch 481 | train loss 0.4677 mae 0.7948 | val loss 0.5878 mae 0.8375
# epoch 482 | train loss 0.4645 mae 0.7903 | val loss 0.5940 mae 0.8332
# epoch 483 | train loss 0.4654 mae 0.7941 | val loss 0.5962 mae 0.8314
# epoch 484 | train loss 0.4665 mae 0.7927 | val loss 0.5880 mae 0.8314
# epoch 485 | train loss 0.4655 mae 0.7932 | val loss 0.5898 mae 0.8335
# epoch 486 | train loss 0.4683 mae 0.7938 | val loss 0.5900 mae 0.8298
# epoch 487 | train loss 0.4687 mae 0.7923 | val loss 0.5914 mae 0.8285
# epoch 488 | train loss 0.4663 mae 0.7964 | val loss 0.6023 mae 0.8369
# epoch 489 | train loss 0.4662 mae 0.7909 | val loss 0.6009 mae 0.8357
# epoch 490 | train loss 0.4667 mae 0.7958 | val loss 0.6043 mae 0.8261
# epoch 491 | train loss 0.4655 mae 0.7921 | val loss 0.5975 mae 0.8277
# epoch 492 | train loss 0.4670 mae 0.7944 | val loss 0.5975 mae 0.8303
# epoch 493 | train loss 0.4660 mae 0.7936 | val loss 0.5806 mae 0.8328
# epoch 494 | train loss 0.4652 mae 0.7912 | val loss 0.6017 mae 0.8375
# epoch 495 | train loss 0.4673 mae 0.7941 | val loss 0.5958 mae 0.8285
# epoch 496 | train loss 0.4656 mae 0.7926 | val loss 0.5788 mae 0.8293
# epoch 497 | train loss 0.4647 mae 0.7897 | val loss 0.5936 mae 0.8308
# epoch 498 | train loss 0.4636 mae 0.7916 | val loss 0.5991 mae 0.8296
# epoch 499 | train loss 0.4635 mae 0.7937 | val loss 0.5913 mae 0.8359
# epoch 500 | train loss 0.4641 mae 0.7903 | val loss 0.6080 mae 0.8277
# epoch 501 | train loss 0.4647 mae 0.7933 | val loss 0.5952 mae 0.8298
# epoch 502 | train loss 0.4671 mae 0.7921 | val loss 0.5852 mae 0.8345
# epoch 503 | train loss 0.4644 mae 0.7914 | val loss 0.5911 mae 0.8259
# epoch 504 | train loss 0.4625 mae 0.7917 | val loss 0.6009 mae 0.8316
# epoch 505 | train loss 0.4656 mae 0.7925 | val loss 0.5965 mae 0.8347
# epoch 506 | train loss 0.4658 mae 0.7925 | val loss 0.5840 mae 0.8277
# epoch 507 | train loss 0.4663 mae 0.7949 | val loss 0.5930 mae 0.8298
# epoch 508 | train loss 0.4657 mae 0.7918 | val loss 0.5925 mae 0.8365
# epoch 509 | train loss 0.4631 mae 0.7905 | val loss 0.5998 mae 0.8355
# epoch 510 | train loss 0.4647 mae 0.7928 | val loss 0.5950 mae 0.8396
# epoch 511 | train loss 0.4654 mae 0.7918 | val loss 0.5862 mae 0.8242
# epoch 512 | train loss 0.4641 mae 0.7891 | val loss 0.6024 mae 0.8301
# epoch 513 | train loss 0.4657 mae 0.7953 | val loss 0.5946 mae 0.8324
# epoch 514 | train loss 0.4633 mae 0.7921 | val loss 0.5929 mae 0.8294
# epoch 515 | train loss 0.4650 mae 0.7921 | val loss 0.5968 mae 0.8254
# epoch 516 | train loss 0.4634 mae 0.7926 | val loss 0.5893 mae 0.8360
# epoch 517 | train loss 0.4643 mae 0.7906 | val loss 0.5971 mae 0.8333
# epoch 518 | train loss 0.4620 mae 0.7914 | val loss 0.6017 mae 0.8306
# epoch 519 | train loss 0.4632 mae 0.7905 | val loss 0.5903 mae 0.8424
# epoch 520 | train loss 0.4625 mae 0.7936 | val loss 0.5931 mae 0.8331
# epoch 521 | train loss 0.4658 mae 0.7902 | val loss 0.5911 mae 0.8270
# epoch 522 | train loss 0.4644 mae 0.7925 | val loss 0.5917 mae 0.8302
# epoch 523 | train loss 0.4633 mae 0.7921 | val loss 0.5884 mae 0.8280
# epoch 524 | train loss 0.4658 mae 0.7923 | val loss 0.5849 mae 0.8351
# epoch 525 | train loss 0.4645 mae 0.7936 | val loss 0.6098 mae 0.8341
# epoch 526 | train loss 0.4634 mae 0.7932 | val loss 0.5971 mae 0.8316
# epoch 527 | train loss 0.4598 mae 0.7896 | val loss 0.6051 mae 0.8299
# epoch 528 | train loss 0.4614 mae 0.7915 | val loss 0.6124 mae 0.8252
# epoch 529 | train loss 0.4667 mae 0.7927 | val loss 0.5813 mae 0.8321
# epoch 530 | train loss 0.4628 mae 0.7907 | val loss 0.6051 mae 0.8354
# epoch 531 | train loss 0.4617 mae 0.7900 | val loss 0.5922 mae 0.8320
# epoch 532 | train loss 0.4624 mae 0.7911 | val loss 0.6054 mae 0.8300
# epoch 533 | train loss 0.4640 mae 0.7922 | val loss 0.5940 mae 0.8344
# epoch 534 | train loss 0.4632 mae 0.7916 | val loss 0.6063 mae 0.8260
# epoch 535 | train loss 0.4673 mae 0.7943 | val loss 0.5934 mae 0.8306
# epoch 536 | train loss 0.4623 mae 0.7914 | val loss 0.5939 mae 0.8316
# epoch 537 | train loss 0.4651 mae 0.7923 | val loss 0.5949 mae 0.8296
# epoch 538 | train loss 0.4662 mae 0.7928 | val loss 0.5999 mae 0.8317
# epoch 539 | train loss 0.4658 mae 0.7924 | val loss 0.5966 mae 0.8335
# epoch 540 | train loss 0.4600 mae 0.7898 | val loss 0.5937 mae 0.8387
# epoch 541 | train loss 0.4616 mae 0.7915 | val loss 0.5933 mae 0.8329
# epoch 542 | train loss 0.4643 mae 0.7922 | val loss 0.5942 mae 0.8256
# epoch 543 | train loss 0.4628 mae 0.7891 | val loss 0.6026 mae 0.8353
# epoch 544 | train loss 0.4630 mae 0.7907 | val loss 0.5880 mae 0.8388
# epoch 545 | train loss 0.4607 mae 0.7904 | val loss 0.6010 mae 0.8268
# epoch 546 | train loss 0.4650 mae 0.7929 | val loss 0.5933 mae 0.8309
# epoch 547 | train loss 0.4646 mae 0.7895 | val loss 0.5965 mae 0.8319
# epoch 548 | train loss 0.4631 mae 0.7937 | val loss 0.5928 mae 0.8429
# epoch 549 | train loss 0.4639 mae 0.7924 | val loss 0.5950 mae 0.8264
# epoch 550 | train loss 0.4654 mae 0.7890 | val loss 0.5986 mae 0.8251
# epoch 551 | train loss 0.4633 mae 0.7927 | val loss 0.5849 mae 0.8367
# epoch 552 | train loss 0.4636 mae 0.7907 | val loss 0.6104 mae 0.8314
# epoch 553 | train loss 0.4631 mae 0.7927 | val loss 0.5962 mae 0.8331
# epoch 554 | train loss 0.4623 mae 0.7901 | val loss 0.6089 mae 0.8296
# epoch 555 | train loss 0.4647 mae 0.7922 | val loss 0.5914 mae 0.8345
# epoch 556 | train loss 0.4637 mae 0.7928 | val loss 0.5951 mae 0.8274
# epoch 557 | train loss 0.4625 mae 0.7901 | val loss 0.5935 mae 0.8314
# epoch 558 | train loss 0.4613 mae 0.7921 | val loss 0.5954 mae 0.8277
# epoch 559 | train loss 0.4616 mae 0.7890 | val loss 0.5983 mae 0.8339
# epoch 560 | train loss 0.4609 mae 0.7890 | val loss 0.6038 mae 0.8270
# epoch 561 | train loss 0.4616 mae 0.7915 | val loss 0.6006 mae 0.8342
# epoch 562 | train loss 0.4638 mae 0.7936 | val loss 0.5915 mae 0.8386
# epoch 563 | train loss 0.4608 mae 0.7897 | val loss 0.6103 mae 0.8245
# epoch 564 | train loss 0.4622 mae 0.7914 | val loss 0.5833 mae 0.8328
# epoch 565 | train loss 0.4623 mae 0.7904 | val loss 0.6056 mae 0.8354
# epoch 566 | train loss 0.4601 mae 0.7891 | val loss 0.6011 mae 0.8286
# epoch 567 | train loss 0.4630 mae 0.7916 | val loss 0.5930 mae 0.8319
# epoch 568 | train loss 0.4619 mae 0.7921 | val loss 0.6046 mae 0.8276
# epoch 569 | train loss 0.4605 mae 0.7876 | val loss 0.5908 mae 0.8346
# epoch 570 | train loss 0.4614 mae 0.7930 | val loss 0.6004 mae 0.8305
# epoch 571 | train loss 0.4615 mae 0.7888 | val loss 0.6012 mae 0.8290
# epoch 572 | train loss 0.4628 mae 0.7916 | val loss 0.5949 mae 0.8346
# epoch 573 | train loss 0.4632 mae 0.7902 | val loss 0.6045 mae 0.8305
# epoch 574 | train loss 0.4627 mae 0.7911 | val loss 0.5965 mae 0.8292
# epoch 575 | train loss 0.4633 mae 0.7922 | val loss 0.5957 mae 0.8356
# epoch 576 | train loss 0.4651 mae 0.7934 | val loss 0.5936 mae 0.8296
# epoch 577 | train loss 0.4622 mae 0.7910 | val loss 0.5970 mae 0.8297
# epoch 578 | train loss 0.4638 mae 0.7913 | val loss 0.5964 mae 0.8285
# epoch 579 | train loss 0.4612 mae 0.7924 | val loss 0.5936 mae 0.8355
# epoch 580 | train loss 0.4644 mae 0.7905 | val loss 0.5987 mae 0.8294
# epoch 581 | train loss 0.4608 mae 0.7903 | val loss 0.5956 mae 0.8356
# epoch 582 | train loss 0.4628 mae 0.7914 | val loss 0.5968 mae 0.8409
# epoch 583 | train loss 0.4616 mae 0.7931 | val loss 0.6041 mae 0.8285
# epoch 584 | train loss 0.4627 mae 0.7896 | val loss 0.6136 mae 0.8284
# epoch 585 | train loss 0.4623 mae 0.7923 | val loss 0.6068 mae 0.8288
# epoch 586 | train loss 0.4623 mae 0.7902 | val loss 0.6055 mae 0.8284
# epoch 587 | train loss 0.4610 mae 0.7903 | val loss 0.5918 mae 0.8439
# epoch 588 | train loss 0.4611 mae 0.7874 | val loss 0.6011 mae 0.8303
# epoch 589 | train loss 0.4671 mae 0.7967 | val loss 0.5997 mae 0.8302
# epoch 590 | train loss 0.4655 mae 0.7888 | val loss 0.6019 mae 0.8347
# epoch 591 | train loss 0.4630 mae 0.7947 | val loss 0.5976 mae 0.8317
# epoch 592 | train loss 0.4611 mae 0.7878 | val loss 0.5990 mae 0.8310
# epoch 593 | train loss 0.4615 mae 0.7927 | val loss 0.5939 mae 0.8292
# epoch 594 | train loss 0.4628 mae 0.7899 | val loss 0.5991 mae 0.8326
# epoch 595 | train loss 0.4597 mae 0.7904 | val loss 0.6013 mae 0.8293
# epoch 596 | train loss 0.4617 mae 0.7911 | val loss 0.6014 mae 0.8299
# epoch 597 | train loss 0.4585 mae 0.7897 | val loss 0.6206 mae 0.8279
# epoch 598 | train loss 0.4607 mae 0.7904 | val loss 0.6001 mae 0.8350
# epoch 599 | train loss 0.4572 mae 0.7862 | val loss 0.6022 mae 0.8300
# epoch 600 | train loss 0.4586 mae 0.7903 | val loss 0.5916 mae 0.8328
# epoch 601 | train loss 0.4585 mae 0.7891 | val loss 0.5920 mae 0.8293
# epoch 602 | train loss 0.4595 mae 0.7881 | val loss 0.6076 mae 0.8334
# epoch 603 | train loss 0.4617 mae 0.7911 | val loss 0.5975 mae 0.8279
# epoch 604 | train loss 0.4630 mae 0.7919 | val loss 0.6008 mae 0.8316
# epoch 605 | train loss 0.4598 mae 0.7901 | val loss 0.5979 mae 0.8302
# epoch 606 | train loss 0.4583 mae 0.7884 | val loss 0.6099 mae 0.8290
# epoch 607 | train loss 0.4614 mae 0.7927 | val loss 0.5910 mae 0.8522
# epoch 608 | train loss 0.4644 mae 0.7916 | val loss 0.6110 mae 0.8293
# epoch 609 | train loss 0.4572 mae 0.7867 | val loss 0.6094 mae 0.8269
# epoch 610 | train loss 0.4617 mae 0.7934 | val loss 0.5886 mae 0.8366
# epoch 611 | train loss 0.4593 mae 0.7873 | val loss 0.6176 mae 0.8275

# %% [markdown]
# ## Prepare validation data for experiments
#
# Note, for **ego-subgraph evaluation**, we do **not** try to transfer precompute exact-ring marker fractions to the subgraphs. Instead, the ring-based models recompute features on the ego-subgraphs on the fly.
#
# This is fine here because:
# - the subgraphs are built with radius `K_MAX`,
# - we evaluate **only the center node** of each subgraph,
# - therefore the center node has access to its full $k \leq K_{MAX}$ neighborhood inside the subgraph.
#
# So the center-node ring features computed on the subgraph are exact, even if boundary nodes inside the subgraph would not have exact full-graph ring features.

# %%
from src.data.subgraphs import build_ego_subgraphs_for_dataset 

val_subgraphs  = build_ego_subgraphs_for_dataset(
    g_val,
    num_hops=K_MAX,
    max_centers_per_graph=None, 
    seed=0,
)

# %% [markdown]
# From all the subgraphs in the validation set, we sample to have coverage of all marker combinations

# %%
from src.data.subgraph_sampling import sample_subgraphs_coverage, print_sampling_summary

sampled_val_subgraphs, sample_info = sample_subgraphs_coverage(
    val_subgraphs,
    marker_names=marker_names,
    k_hops=K_MAX,          # or the k_hops you will perturb over
    max_subgraphs=5000,          # your budget
    min_center_count=40,
    min_pair_count=25,
    seed=0,
)

print_sampling_summary(sample_info, marker_names)
# Out:
# Selected 5000 / 76441 subgraphs
#
# Center coverage:
# LGR5          covered= 952  target=  40  available=12330  OK
# Chroma        covered= 126  target=  40  available= 372  OK
# AldoB         covered=1922  target=  40  available=29402  OK
# Agr2          covered= 318  target=  40  available=3581  OK
# Serotonin     covered= 129  target=  40  available= 321  OK
# Lysozyme      covered= 204  target=  40  available=1772  OK
# KI67          covered=1664  target=  40  available=24562  OK
#
# Unsatisfied center markers: []
# Unsatisfied pair features: 1

# %% [markdown]
# ### Setup helper functions for analysis

# %%
from src.analysis.prediction_analysis import eval_model_per_marker

def evaluate_family_models(trained_models, eval_subgraphs, device, scale, center):
    all_results = {}

    aggregate_keys = ["any_marker", "no_marker", "all_nodes"]
    aggregate_metric_keys = [
        "n",
        "mse_model", "sem_mse_model",
        "mse_base", "sem_mse_base",
        "var_model", "sem_var_model",
        "var_base", "sem_var_base",
        "nll_model", "sem_nll_model",
        "nll_base", "sem_nll_base",
        "rho", "pval",
    ]

    for family, models in trained_models.items():
        fam_mse_model = []
        fam_sem_mse_model = []
        fam_var_model = []
        fam_sem_var_model = []
        fam_nll_model = []
        fam_sem_nll_model = []
        fam_rho_marker = []
        fam_pval_marker = []
        fam_n_pos_corr = []
        fam_rho_global = []
        fam_pval_global = []

        fam_mse_base = None
        fam_var_base = None
        fam_sem_mse_base = None
        fam_nll_base = None
        fam_sem_nll_base = None

        # aggregate storage
        fam_aggregate = {
            agg_name: {metric: [] for metric in aggregate_metric_keys}
            for agg_name in aggregate_keys
        }

        for model in models:
            model.eval()
            out = eval_model_per_marker(
                model,
                eval_subgraphs,
                device,
                scale,
                center,
                center_only=True,
            )

            fam_mse_model.append(out["mse_model"])
            fam_sem_mse_model.append(out["sem_mse_model"])
            fam_var_model.append(out["var_model"])
            fam_sem_var_model.append(out["sem_var_model"])
            fam_nll_model.append(out["nll_model"])
            fam_sem_nll_model.append(out["sem_nll_model"])
            fam_rho_marker.append(out["rho_marker"])
            fam_pval_marker.append(out["pval_marker"])
            fam_n_pos_corr.append(out["n_pos_corr"])
            fam_rho_global.append(out["rho_global"])
            fam_pval_global.append(out["pval_global"])

            for agg_name in aggregate_keys:
                agg_out = out["aggregate"][agg_name]
                for metric in aggregate_metric_keys:
                    fam_aggregate[agg_name][metric].append(agg_out[metric])

            if fam_mse_base is None:
                fam_mse_base = out["mse_base"]
                fam_var_base = out["var_base"]
                fam_sem_mse_base = out["sem_mse_base"]
                fam_nll_base = out["nll_base"]
                fam_sem_nll_base = out["sem_nll_base"]

        # stack aggregate arrays across model depth / family member index
        fam_aggregate_stacked = {}
        for agg_name in aggregate_keys:
            fam_aggregate_stacked[agg_name] = {}
            for metric in aggregate_metric_keys:
                vals = fam_aggregate[agg_name][metric]
                fam_aggregate_stacked[agg_name][metric] = np.asarray(vals, dtype=float)

        all_results[family] = {
            "mse_model": np.stack(fam_mse_model, axis=0),
            "sem_mse_model": np.stack(fam_sem_mse_model, axis=0),
            "var_model": np.stack(fam_var_model, axis=0),
            "sem_var_model": np.stack(fam_sem_var_model, axis=0),
            "nll_model": np.stack(fam_nll_model, axis=0),
            "sem_nll_model": np.stack(fam_sem_nll_model, axis=0),
            "rho_marker": np.stack(fam_rho_marker, axis=0),
            "pval_marker": np.stack(fam_pval_marker, axis=0),
            "n_pos_corr": np.stack(fam_n_pos_corr, axis=0),
            "rho_global": np.asarray(fam_rho_global, dtype=float),
            "pval_global": np.asarray(fam_pval_global, dtype=float),
            "mse_base": fam_mse_base,
            "var_base": fam_var_base,
            "sem_mse_base": fam_sem_mse_base,
            "nll_base": fam_nll_base,
            "sem_nll_base": fam_sem_nll_base,
            "aggregate": fam_aggregate_stacked,
        }

    return all_results

# %% [markdown]
# ## Experiment 1: Original organoid graphs
#
# This establishes the baseline behavior of each model family when trained on the original full graphs and evaluated on the same sampled validation centers.
#
# Because we evaluate only the **center node** of each ego-subgraph, the sampled validation set gives us:
# - good control over rare center markers,
# - much cheaper evaluation than using every node in every organoid,
# - direct markerwise comparison against the baseline mean curvature per center marker.

# %%
all_results_exp1 = evaluate_family_models(
    trained_models=trained_model_families,
    eval_subgraphs=sampled_val_subgraphs,
    device=device,
    scale=scale,
    center=center,
)

# %%
from src.plotting.depth_scan import plot_markerwise_metric_vs_depth, plot_all_aggregates_metric_vs_depth
plt.rcParams.update({
    "axes.spines.top": True,
    "axes.spines.right": True,
    "axes.grid": True,
    "grid.alpha": 0.25,
})

family_colors = {
    "GIN":          "#1f77b4",
    "ring-fraction":"#ff7f0e",
    "ring-size":    "#9467bd",
}

family_order = [
    "GIN",
    "ring-fraction",
    "ring-size",
]


plot_markerwise_metric_vs_depth(
    all_results=all_results_exp1,
    depths=depths,
    marker_names=marker_names,
    metric_key="mse_model",
    sem_key="sem_mse_model",
    baseline_key="mse_base",
    baseline_sem_key="sem_mse_base",
    ylabel="Mean Squared Error",
    title="Validation MSE vs depth",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %%
plot_all_aggregates_metric_vs_depth(
    all_results_exp1,
    depths,
    aggregate_keys=("all_nodes",),
    metric_key="mse_model",
    sem_key="sem_mse_model",
    baseline_key="mse_base",
    baseline_sem_key="sem_mse_base",
    ylabel="Mean Squared Error",
    title="MSE vs depth",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %%
plot_markerwise_metric_vs_depth(
    all_results=all_results_exp1,
    depths=depths,
    marker_names=marker_names,
    metric_key="nll_model",
    sem_key="sem_nll_model",
    baseline_key="nll_base",
    baseline_sem_key="sem_nll_base",
    ylabel="Negative Log-Likelihood",
    title="Validation NLL vs depth",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %%
plot_all_aggregates_metric_vs_depth(
    all_results_exp1,
    depths,
    aggregate_keys=("all_nodes",),
    metric_key="nll_model",
    sem_key="sem_nll_model",
    baseline_key="nll_base",
    baseline_sem_key="sem_nll_base",
    ylabel="Negative Log-Likelihood",
    title="NLL vs depth",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %%
plot_markerwise_metric_vs_depth(
    all_results=all_results_exp1,
    depths=depths,
    marker_names=marker_names,
    metric_key="rho_marker",
    baseline_hline=0.0,
    ylabel="Spearman corr(var, residual²)",
    title="Uncertainty-error correlation",
    family_order=family_order,
    family_colors=family_colors,
    sharey=True,
)
plt.show()

# %%
plot_all_aggregates_metric_vs_depth(
    all_results_exp1,
    depths,
    aggregate_keys=("all_nodes",),
    metric_key="rho",
    baseline_hline=0.0,
    ylabel="Spearman corr(var, residual²)",
    title="Uncertainty-error correlation vs depth",
    family_order=family_order,
    family_colors=family_colors,
)

plt.show()

# %% [markdown]
# ## Experiment 2: Center-preserving neighborhood permutation (evaluation-time ablation)
#
# In this experiment we **reuse the models trained on the original organoid graphs** and evaluate them under controlled perturbations of neighborhood marker composition.
#
# The goal is to test how much predictive signal comes from **neighborhood organization**, beyond what is already explained by the **identity of the center cell**.
#
# ### Procedure
#
# 1. We first sample a fixed set of validation centers (balanced across markers).
#    These centers are reused in all evaluation conditions to ensure fair markerwise comparisons.
#
# 2. Marker feature rows are then **randomly permuted within each validation organoid**.
#    This destroys spatial correlations between marker identity and curvature while preserving:
#
#    * global marker frequencies,
#    * graph topology,
#    * organoid-level composition.
#
# 3. Ego-subgraphs are rebuilt around the sampled centers.
#    For each subgraph, the **center marker row is restored to its original value**, while all neighborhood markers remain permuted.
#
# ### Interpretation
#
# This intervention removes information about **which markers surround a given cell**, while keeping the center marker and curvature target unchanged.
#
# Any degradation in performance relative to evaluation on original subgraphs therefore reflects the model’s reliance on **informative neighborhood composition**.
#
# This differs from training on permuted graphs, which would destroy both center-marker and neighborhood-marker alignment and would act as a much stronger (and less interpretable) null model.
#
# ### What to monitor in the analysis
#
# * Markerwise changes in MSE / NLL relative to baseline
# * Dependence of performance drop on model depth
# * Differences between model families (GNN vs ring models)
# * Behaviour of predicted variance under permutation
# * Whether performance approaches the marker-conditional baseline
#
# These observations help disentangle how much curvature information is encoded in **center identity vs spatial marker organization**.

# %%
from src.data.permutation import permute_graph_features_within_organoid, build_center_preserving_permuted_subgraphs

# Build center-preserving permuted validation ego-subgraphs for exactly the same sampled centers.
perm_val_subgraphs = build_center_preserving_permuted_subgraphs(
    graphs=g_val,
    sampled_subgraphs=sampled_val_subgraphs,
    num_hops=K_MAX,
    permute_graphs_fn=permute_graph_features_within_organoid,
    seed=0,
)

print(f"Center-preserving permuted validation subgraphs: {len(perm_val_subgraphs)}")
# Out:
# Center-preserving permuted validation subgraphs: 5000

# %%
all_results_exp2 = evaluate_family_models(
    trained_models=trained_model_families,
    eval_subgraphs=perm_val_subgraphs,
    device=device,
    scale=scale,
    center=center,
)

# %%
plot_markerwise_metric_vs_depth(
    all_results=all_results_exp2,
    depths=depths,
    marker_names=marker_names,
    metric_key="mse_model",
    sem_key="sem_mse_model",
    baseline_key="mse_base",
    baseline_sem_key="sem_mse_base",
    ylabel="Mean Squared Error",
    title="Experiment 2: center-preserving permuted validation MSE",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %%
plot_all_aggregates_metric_vs_depth(
    all_results_exp2,
    depths,
    aggregate_keys=("all_nodes",),
    metric_key="mse_model",
    sem_key="sem_mse_model",
    baseline_key="mse_base",
    baseline_sem_key="sem_mse_base",
    ylabel="Mean Squared Error",
    title="MSE vs depth",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %%
plot_markerwise_metric_vs_depth(
    all_results=all_results_exp2,
    depths=depths,
    marker_names=marker_names,
    metric_key="nll_model",
    sem_key="sem_nll_model",
    baseline_key="nll_base",
    baseline_sem_key="sem_nll_base",
    ylabel="Negative Log-Likelihood",
    title="Experiment 2: center-preserving permuted validation NLL",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %%
plot_all_aggregates_metric_vs_depth(
    all_results_exp2,
    depths,
    aggregate_keys=("all_nodes",),
    metric_key="nll_model",
    sem_key="sem_nll_model",
    baseline_key="nll_base",
    baseline_sem_key="sem_nll_base",
    ylabel="Negative Log-Likelihood",
    title="NLL vs depth",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %%
plot_markerwise_metric_vs_depth(
    all_results=all_results_exp2,
    depths=depths,
    marker_names=marker_names,
    metric_key="rho_marker",
    baseline_hline=0.0,
    ylabel="Spearman corr(var, residual²)",
    title="Experiment 2: uncertainty-error correlation",
    family_order=family_order,
    family_colors=family_colors,
    sharey=True,
)
plt.show()

# %%
plot_all_aggregates_metric_vs_depth(
    all_results_exp2,
    depths,
    aggregate_keys=("all_nodes",),
    metric_key="rho",
    baseline_hline=0.0,
    ylabel="Spearman corr(var, residual²)",
    title="Uncertainty-error correlation vs depth",
    family_order=family_order,
    family_colors=family_colors,
)
plt.show()

# %% [markdown]
# ## Experiment 3: Ring-preserving permutation (coarse vs fine neighborhood structure)
#
# In this experiment we again **reuse the models trained on the original organoid graphs**, but evaluate them under a milder perturbation of neighborhood marker organization.
#
# The goal is to distinguish whether predictive signal comes primarily from:
#
# * the **coarse composition of markers at different spatial scales**, or
# * the **finer spatial arrangement and topology of cells within those scales**.
#
# ### Procedure
#
# 1. As in Experiment 2, we use the same fixed set of sampled validation centers to ensure fair markerwise comparisons.
#
# 2. Within each validation organoid, marker features are **permuted only within each k-hop ring** around every node.
#    This preserves:
#
#    * how many cells of each marker type occur in each hop shell,
#    * overall organoid composition,
#    * graph connectivity.
#
#    However, it destroys:
#
#    * the detailed spatial ordering of cells inside each ring,
#    * local clustering patterns,
#    * directional gradients and niche geometry.
#
# 3. Ego-subgraphs are rebuilt around the sampled centers and evaluated in the same way as before.
#
# ### Interpretation
#
# Compared to full neighborhood permutation (Experiment 2), this intervention removes only **fine spatial structure** while keeping **ring-level composition intact**.
#
# Therefore:
#
# * If performance drops strongly relative to the original graphs,
#   the model relies on **finer spatial organization or topology**.
#
# * If performance remains similar,
#   most predictive signal is already captured by **coarse marker composition at different distances**.
#
# Comparing the sensitivity of different model families (e.g. GNN vs ring-based models) helps clarify whether additional spatial expressivity translates into improved biological signal extraction.
#
# ### What to monitor in the analysis
#
# * Markerwise performance changes relative to both:
#
#   * original evaluation
#   * fully permuted neighborhoods (Experiment 2)
#
# * Depth dependence of the performance gap
#
# * Differences between GNN and ring-based models
#
# * Behaviour of predicted variance and uncertainty calibration
#
# Together, these comparisons help quantify how curvature prediction depends on **multi-scale neighborhood composition versus fine spatial arrangement**.

# %%
from src.data.permutation import permute_ego_neighborhood_within_rings

ring_permuted_val_subgraphs = permute_ego_neighborhood_within_rings(
    sampled_val_subgraphs,
    k_hops=K_MAX,
)

# %%
all_results_exp3_gin = evaluate_family_models(
    trained_models={"GIN": trained_model_families["GIN"]},
    eval_subgraphs=ring_permuted_val_subgraphs,
    device=device,
    scale=scale,
    center=center,
)

# %%
import math 

def plot_two_result_sets_one_family(results_a, results_b, family, metric_key, sem_key=None, baseline_key=None,
                                    baseline_sem_key=None, ylabel="", title="", label_a="original",
                                    label_b="ring-permuted", color_a="#1f77b4", color_b="#d62728"):
    n_markers = len(marker_names)
    n_cols = 2
    n_rows = math.ceil(n_markers / n_cols)

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 3.2 * n_rows), sharex=True)
    axes = np.atleast_1d(axes).ravel()

    for ax, mi, mname in zip(axes, range(n_markers), marker_names):
        y_a = results_a[family][metric_key][:, mi]
        y_b = results_b[family][metric_key][:, mi]

        ax.plot(depths, y_a, "-o", color=color_a, linewidth=2, markersize=4, label=label_a)
        ax.plot(depths, y_b, "-o", color=color_b, linewidth=2, markersize=4, label=label_b)

        if sem_key is not None:
            s_a = results_a[family][sem_key][:, mi]
            s_b = results_b[family][sem_key][:, mi]
            ax.fill_between(depths, y_a - s_a, y_a + s_a, color=color_a, alpha=0.15)
            ax.fill_between(depths, y_b - s_b, y_b + s_b, color=color_b, alpha=0.15)

        if baseline_key is not None:
            y0 = results_a[family][baseline_key][mi]
            ax.axhline(y0, linestyle="--", color="#888888", alpha=0.8, label="baseline")
            if baseline_sem_key is not None:
                s0 = results_a[family][baseline_sem_key][mi]
                ax.fill_between(depths, y0 - s0, y0 + s0, color="#888888", alpha=0.12)

        ax.set_title(mname)
        ax.set_xlabel("depth / k-hops")
        ax.set_ylabel(ylabel)
        ax.set_xticks(depths)
        ax.legend(fontsize=7)

    for ax in axes[n_markers:]:
        ax.set_visible(False)

    fig.suptitle(title, y=1.02)
    plt.tight_layout()
    return fig


def plot_two_result_sets_one_family_aggregate(
    results_a,
    results_b,
    family,
    depths,
    *,
    aggregate_key="all_nodes",
    metric_key,
    sem_key=None,
    baseline_key=None,
    baseline_sem_key=None,
    ylabel="",
    title="",
    label_a="original",
    label_b="ring-permuted",
    color_a="#1f77b4",
    color_b="#d62728",
    baseline_color="#888888",
    legend_fontsize=8,
    fill_alpha=0.15,
    baseline_fill_alpha=0.12,
    figsize=(7, 4),
):
    if family not in results_a:
        raise KeyError(f"{family!r} not found in results_a")
    if family not in results_b:
        raise KeyError(f"{family!r} not found in results_b")

    x = np.asarray(depths)

    fig, ax = plt.subplots(figsize=figsize)

    y_a = np.asarray(results_a[family]["aggregate"][aggregate_key][metric_key], dtype=float)
    y_b = np.asarray(results_b[family]["aggregate"][aggregate_key][metric_key], dtype=float)

    ax.plot(x, y_a, "-o", color=color_a, linewidth=2, markersize=4, label=label_a)
    ax.plot(x, y_b, "-o", color=color_b, linewidth=2, markersize=4, label=label_b)

    if sem_key is not None:
        s_a = np.asarray(results_a[family]["aggregate"][aggregate_key][sem_key], dtype=float)
        s_b = np.asarray(results_b[family]["aggregate"][aggregate_key][sem_key], dtype=float)

        ax.fill_between(x, y_a - s_a, y_a + s_a, color=color_a, alpha=fill_alpha)
        ax.fill_between(x, y_b - s_b, y_b + s_b, color=color_b, alpha=fill_alpha)

    if baseline_key is not None:
        y0 = results_a[family]["aggregate"][aggregate_key][baseline_key]
        y0 = float(y0[0]) if np.ndim(y0) > 0 else float(y0)

        ax.axhline(y0, linestyle="--", color=baseline_color, alpha=0.8, label="baseline")

        if baseline_sem_key is not None:
            s0 = results_a[family]["aggregate"][aggregate_key][baseline_sem_key]
            s0 = float(s0[0]) if np.ndim(s0) > 0 else float(s0)

            ax.fill_between(x, y0 - s0, y0 + s0, color=baseline_color, alpha=baseline_fill_alpha)

    pretty_names = {
        "all_nodes": "all nodes",
        "any_marker": "marker-positive nodes",
        "no_marker": "marker-negative nodes",
    }

    ax.set_title(pretty_names.get(aggregate_key, aggregate_key))
    ax.set_xlabel("depth / k-hops")
    ax.set_ylabel(ylabel)
    ax.set_xticks(x)
    ax.legend(fontsize=legend_fontsize)

    fig.suptitle(title, y=1.02)
    plt.tight_layout()
    return fig, ax

# %%
plot_two_result_sets_one_family(
    all_results_exp1,
    all_results_exp3_gin,
    family="GIN",
    metric_key="mse_model",
    sem_key="sem_mse_model",
    baseline_key="mse_base",
    baseline_sem_key="sem_mse_base",
    ylabel="Mean Squared Error",
    title="Experiment 3: GIN on original vs ring-permuted validation subgraphs",
)
plt.show()

# %%
fig, ax = plot_two_result_sets_one_family_aggregate(
    all_results_exp1,
    all_results_exp3_gin,
    family="GIN",
    depths=depths,
    aggregate_key="all_nodes",
    metric_key="mse_model",
    sem_key="sem_mse_model",
    baseline_key="mse_base",
    baseline_sem_key="sem_mse_base",
    ylabel="Mean Squared Error",
    title="",
    label_a="original",
    label_b="ring-permuted",
)
plt.show()

# %%
plot_two_result_sets_one_family(
    all_results_exp1,
    all_results_exp3_gin,
    family="GIN",
    metric_key="rho_marker",
    ylabel="Spearman corr(var, residual²)",
    title="Experiment 3: uncertainty-error correlation for GIN",
)
plt.show()

# %%
fig, ax = plot_two_result_sets_one_family_aggregate(
    all_results_exp1,
    all_results_exp3_gin,
    family="GIN",
    depths=depths,
    aggregate_key="all_nodes",
    metric_key="rho",
    ylabel="Spearman corr(var, residual²)",
    title="",
    label_a="original",
    label_b="ring-permuted",
)
plt.show()
# Out:
# /home/fmoller/Projects/LearningOrganoids/GraphNN/results_experiments/composition_analysis/run_004/figures/ringperm_corr_vs_depth.pdf

# %% [markdown]
# ## Save the results

# %%
import json
import pickle
from pathlib import Path
from datetime import datetime


def save_joint_experiment(save_dir, config, results_by_experiment, notes=None):
    save_dir = Path(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    with open(save_dir / "config.json", "w") as f:
        json.dump(config, f, indent=2)

    with open(save_dir / "results.pkl", "wb") as f:
        pickle.dump(results_by_experiment, f)

    meta = {
        "timestamp": datetime.now().isoformat(),
        "notes": notes,
        "experiments": list(results_by_experiment.keys()),
    }
    with open(save_dir / "meta.json", "w") as f:
        json.dump(meta, f, indent=2)

    print(f"Saved joint experiment → {save_dir}")

# %%
joint_config = {
    "experiment_group": "composition_analysis",

    "model_families": list(trained_model_families.keys()),
    "depths": depths.tolist(),

    "hidden_dim": base_hidden_dim,
    "dropout": base_dropout,
    "norm": base_norm,
    "K_MAX": K_MAX,

    "train_config": {
        "loss_name": cfg.loss_name,
        "lr": cfg.lr,
        "batch_size": cfg.batch_size,
        "max_epochs": cfg.max_epochs,
        "patience": cfg.patience,
        "num_workers": cfg.num_workers,
    },

    "n_train_graphs": len(g_train),
    "n_val_graphs": len(g_val),
    "n_sampled_subgraphs": len(sampled_val_subgraphs),

    "marker_names": list(marker_names),

    "sampling": {
        "seed": 0,
        "center_balanced": True,
    },
}

# %%
# results_by_experiment = {
#     "exp1_original": all_results_exp1,
#     "exp2_center_preserving_permuted": all_results_exp2,
#     "exp3_ring_preserving_permuted": all_results_exp3_gin,
# }

# save_dir = PROJECT_ROOT / "results_experiments" / "composition_analysis" / "run_004"

# save_joint_experiment(
#     save_dir=save_dir,
#     config=joint_config,
#     results_by_experiment=results_by_experiment,
#     notes="Original + center-preserving permutation + ring-preserving permutation",
# )
# Out:
# Saved joint experiment → /home/fmoller/Projects/LearningOrganoids/GraphNN/experiments/composition_analysis/run_004
